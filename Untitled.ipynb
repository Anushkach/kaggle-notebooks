# %%
# !pip install scikit-lego
# !pip install lightgbm
# !pip install category-encoders

# %%
# %%time

from gc import collect
from warnings import filterwarnings
filterwarnings('ignore')
from IPython.display import clear_output

clear_output()

import xgboost as xgb, lightgbm as lgb, sklego
print(f'---> Current XGBoost = {xgb.__version__} | LightGBM = {lgb.__version__} | SKLego = {sklego.__version__}')
print()
collect()
# Out:
# ---> Current XGBoost = 2.0.2 | LightGBM = 4.1.0 | SKLego = 0.6.16
#
# CPU times: user 1.22 s, sys: 365 ms, total: 1.59 s
# Wall time: 2.22 s
# 0

# %%
# %%time

# General Library Imports
from copy import deepcopy
import pandas as pd
import numpy as np
import re
from scipy.stats import mode, kstest, normaltest, shapiro, anderson, jarque_bera;
from collections import Counter
from itertools import product
from colorama import Fore, Style, init
from warnings import filterwarnings
filterwarnings('ignore')
import joblib
import os

from tqdm.notebook import tqdm
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib.colors import ListedColormap as LCM
# %matplotlib inline

from pprint import pprint

print()
collect()
clear_output()
# Out:
# CPU times: user 254 ms, sys: 11.7 ms, total: 266 ms
# Wall time: 330 ms

# %%
# %%time 

# Importing model and pipeline specifics
from category_encoders import OrdinalEncoder, OneHotEncoder

# Pipeline specifics
from sklearn.preprocessing import (RobustScaler,
                                   MinMaxScaler,
                                   StandardScaler,
                                   FunctionTransformer as FT,
                                   PowerTransformer);
from sklearn.impute import SimpleImputer as SI;
from sklearn.model_selection import (RepeatedStratifiedKFold as RSKF,
                                     StratifiedKFold as SKF,
                                     KFold,
                                     RepeatedKFold as RKF,
                                     cross_val_score,
                                     cross_val_predict);
from sklearn.inspection import permutation_importance;
from sklearn.feature_selection import mutual_info_classif, RFE;
from sklearn.pipeline import Pipeline, make_pipeline;
from sklearn.base import BaseEstimator, TransformerMixin;
from sklearn.compose import ColumnTransformer;

# Model Training
from sklearn.metrics import median_absolute_error as meae, make_scorer;
from xgboost import XGBRegressor, DMatrix;
from lightgbm import LGBMRegressor, log_evaluation, early_stopping, LGBMClassifier;
from catboost import CatBoostRegressor, Pool;
from sklearn.ensemble import (RandomForestRegressor as RFR,
                              ExtraTreesRegressor as ETR,
                              AdaBoostRegressor as ABR,
                              BaggingRegressor as BR,
                              HistGradientBoostingRegressor as HGBR,
                              GradientBoostingRegressor as GBR);
from sklearn.neighbors import KNeighborsRegressor as KNNR;
from sklearn.svm import SVR;
from sklearn.linear_model import Ridge as RIDGER;

# Ensemble and tuning
import optuna;
from optuna import Trial, trial, create_study;
from optuna.samplers import TPESampler,CmaEsSampler
optuna.logging.set_verbosity=optuna.logging.ERROR;

from sklego.linear_model import LADRegression as LADR;

clear_output();
print();
collect();
# Out:
# CPU times: user 686 ms, sys: 153 ms, total: 839 ms
# Wall time: 1.45 s

# %%
# %%time

# setting rc parameter in seaborn for plots
sns.set({"axes.facecolor"       : "#ffffff",
         "figure.facecolor"     : "#ffffff",
         "axes.edgecolor"       : "#000000",
         "grid.color"           : "#ffffff",
         "font.family"          : ['Cambria'],
         "axes.labelcolor"      : "#000000",
         "xtick.color"          : "#000000",
         "ytick.color"          : "#000000",
         "grid.linewidth"       : 0.75,  
         "grid.linestyle"       : "--",
         "axes.titlecolor"      : '#0099e6',
         'axes.titlesize'       : 8.5,
         'axes.labelweight'     : "bold",
         'legend.fontsize'      : 7.0,
         'legend.title_fontsize': 7.0,
         'font.size'            : 7.5,
         'xtick.labelsize'      : 7.5,
         'ytick.labelsize'      : 7.5,        
        });

# Color printing
def PrintColor(text:str,
               color=Fore.BLUE,
               style=Style.BRIGHT):
    "Prints color outputs using colorma using a text F-string";
    print(style+color+text+Style.RESET_ALL);
    
# making sklearn output as pandas dataframe
from sklearn import set_config;
set_config(transform_output="pandas");
pd.set_option("display.max_columns",50);
pd.set_option("display.max_rows",50);

print();
collect();
# Out:
# CPU times: user 216 ms, sys: 3.77 ms, total: 219 ms
# Wall time: 217 ms

# %% [markdown]
# # Introduction

# %% [markdown]
# | Version<br>Number | Version Details | CV score| Single/ Ensemble|Public LB Score|
# | :-: | --- | :-: | :-: |:-:|
# | **V1** |* No scaling and null treatment <br> * No secondary features <br> * Used original data <br> * 5 x 2 RKF CV <br> * Tree based ML models and Optuna ensemble|0.543611|Optuna blend |0.51966|
# | **V2** |* No scaling and null treatment <br> * No secondary features <br> * Used original data <br> * Cleaned synthetic targets with target-scaling <br> * 5 x 2 RSKF CV with target encoding <br> * Tree based ML models and LAD ensemble|0.516996|LAD |0.49161|
# | **V3** |* No secondary features <br> * Used original data <br> * Cleaned synthetic targets and dropped duplicates in train set <br> * 5 x 2 RKF CV<br> * ML Models and LAD ensemble <br> * Post-processed with train-test duplicates|0.52585|LAD |0.49396|
# | **V4** |* Same as V3 <br> * Used target encoding and RSKF 5x2|0.52429|LAD |0.50145|
# | **V5** |* Same as V3 <br> * Used KFold 10x1 <br> * Used better public score notebooks for blend|0.519862|LAD |0.43467|
# | **V6** |* Used KFold 10x1 <br> * Removed LightGBM from ML models <br> * Used quantile and MedAE objective functions <br> * Used better public score notebooks for blend||LAD ||

# %% [markdown]
# <a id="2.2"></a>
# ## <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:#ffffff; font-size:120%; text-align:left;padding:3.0px; background: #0059b3; border-bottom: 8px solid #e6e6e6" > CONFIGURATION PARAMETERS<br><div>
#
#
# | Parameter         | Description                                             | Possible value choices|
# | ---               | ---                                                     | :-:                   |
# |  version_nb       | Version Number                                          | integer               |
# |  test_req         | Are we testing syntax here?                             | Y/N                   |
# |  test_sample_frac | Sample size for syntax test                             | float(0-1)/ int       |
# |  gpu_switch       | GPU switch                                              | ON/OFF                |
# |  state            | Random state for most purposes                          | integer               |
# |  target           | Target column name                                      | yield                 |
# |  episode          | Episode Number                                          | integer               |
# |  path             | Path for input data files                               |                       |
# |  orig_path        | Path for input original data files                      |                       |
# |  dtl_preproc_req  | Proprocessing required                                  | Y/N                   |
# |  adv_cv_req       | Adversarial CV required                                 | Y/N                   |
# |  ftre_plots_req   | Feature plots required                                  | Y/N                   |
# |  ftre_imp_req     | Feature importance required                             | Y/N                   |
# |  conjoin_orig_data| Conjoin original data                                   | Y/N                   |
# |  drop_nulls       | Drop original data nulls                                | Y/N                   |
# |  sec_ftre_req     | Secondary features required                             | Y/N                   |
# |  scale_req        | Scaling required                                        | Y/N                   |
# |  scl_method       | Scaling method                                          | Z/ Robust/ MinMax     |
# |  enc_method       | Encoding method                                         |-                      |
# |  OH_cols          | Onehot columns                                          |list                   |
# |  tgt_scl_fct      | Target scaling factor                                   |integer                |
# |  tgt_mapper       | Target mapper                                           | dict                  |
# |  drop_tr_req      | Drop extra training elements not in test                | Y/N                   |
# |  baseline_req     | Baseline model required                                 | Y/N                   |
# |  pstprcs_oof      | Post-process OOF after model training                   | Y/N                   |
# |  pstprcs_train    | Post-process OOF during model training for dev-set      | Y/N                   |
# |  pstprcs_test     | Post-process test after training                        | Y/N                   |
# |  ML               | Machine Learning Models                                 | Y/N                   |
# |  use_orig_all_folds| Use original data in all folds                         | Y/N                   |
# |  n_splits         | Number of CV splits                                     | integer               |
# |  n_repeats        | Number of CV repeats                                    | integer               |
# |  nbrnd_erly_stp   | Number of early stopping rounds                         | integer               |
# |  mdl_cv_mthd      | Model CV method name                                    | RKF/ RSKF/ SKF/ KFold |

# %%
# %%time

# configuration class
class CFG:
    '''Configurations class for parameters and CV strategy for tuning and training'''
    
    # Data Preparation
    version_nb = 8;
    test_req = "N";
    test_sample_frac = 0.025;
    gpu_switch = "OFF";
    state = 42;
    target = "Hardness";
    episode = 25;
    path = "/home/jupyter/kaggle-notebooks/Dataset";
    orig_path = "/home/jupyter/kaggle-notebooks/Dataset/Mineral_Dataset_Supplementary_Info.csv";
    
    dtl_preproc_req = "Y";
    adv_cv_req = "N"; # adveserial cross validation
    ftre_plots_req = "N"; # feature plots
    ftre_imp_req = "N"; # feqature importance
    
    # Data transforms and scaling
    conjoin_orig_data = "Y";
    drop_nulls = "Y";
    sec_ftre_req = "N"; # secondary features required
    scale_req = "N";
    
    # keep a value here even if scale_req=N this nis used for linear models
    scl_method="PT";
    enc_method='Label';
    OH_cols=[]; # onehot columns
    tgt_scl_fct=100; # target scaling factor
    
    # model training
    baseline_req="N"; # baseline model required
    pstprcs_oof="Y"; # post process OFF afetr model training | OOF=out of fold
    pstprcs_train="Y";
    pstprc_test="Y";
    ML="Y";
    
    '''Psedo labeling is a technique used to improve model performance by using the 
    models own predictions as additional training data'''
    pseudo_lbl_req     = "N"; 
    pseudolbl_up       = 0.90;
    pseudolbl_low      = 0.05;
    
    use_orig_allfolds  = "N";
    n_splits           = 10 ;
    n_repeats          = 1 ; # repeated kfold cross validation
    nbrnd_erly_stp     = 75 ; # numbe rof early stopping rounds
    mdlcv_mthd         = 'RKF'; # repeated k-fold cross validation
    
    # ensemble
    ensemble_req="Y";
    hill_climb_req="N";
    optuna_req="N";
    LAD_req="Y";
    enscv_method="RKF";
    metric_obj="minimize";
    ntrials=10 if test_req=="Y" else 500;
    
    # Global variables for plotting
    grid_specs={'visible':True,
                'which':'both',
                'linestyle':'--',
                'color':'lightgrey',
                'linewidth':0.75,
               };
    title_specs={'fontsize':9,
                 'fontweight':'bold',
                 'color':'tab:blue'
                };
    
print();
PrintColor(f"--> Configuration done!\n");
collect();
# Out:
# --> Configuration done!
#
# CPU times: user 204 ms, sys: 0 ns, total: 204 ms
# Wall time: 202 ms

# %%
# %%time

# Defining comman functions to be used throughout the conde for comman task

# scaler used for continuous columns
all_scalers={'Robust':RobustScaler(),
             'Z':StandardScaler(),
             'MinMax':MinMaxScaler(),
             'PT':PowerTransformer()};
scaler=all_scalers.get(CFG.scl_method);

# Commonly used strategies for later use
all_cv={'KF':KFold(n_splits=CFG.n_splits,shuffle=True,random_state=CFG.state),
        'RKF':RKF(n_splits= CFG.n_splits, n_repeats = CFG.n_repeats, random_state= CFG.state), # Repeated K-fold cv
        'RSKF': RSKF(n_splits= CFG.n_splits, n_repeats = CFG.n_repeats, random_state= CFG.state), # Repeated stratified k-fold cv
        'SKF' : SKF(n_splits= CFG.n_splits, shuffle = True, random_state= CFG.state)}; # Stratified k-fold cv (*imbalance data)

# defining  competition metrics
def ScoreMetric(ytrue, ypred, tgt_scl_fct=CFG.tgt_scl_fct)->float:
    """
    This function calculates the metric for the competition. 
    ytrue- ground truth array
    ypred- predictions
    returns - metric value (float)
    
    This function necessitates that the predictions array should be flattened.
    """;
    return meae(ytrue,ypred);

def PostProcessPred(preds, post_process="N",tgt_scl_fct=CFG.tgt_scl_fct):
    """
    This is an optional post processing function.
    We correct predictions to be within the specific range.
    """;
    if post_process=="Y":
        preds_pp=np.clip(preds,a_min=0,a_max=10*tgt_scl_fct);
        return preds_pp
    else:
        return preds
    
# Designing custom scorer to use in cross_val_predict and cross_val_score
myscorer = make_scorer(ScoreMetric, 
                       greater_is_better = False if CFG.metric_obj == "minimize" else True, 
                       needs_proba= False,
                      );

# Making a directory to store model objects
if os.path.exists("/home/jupyter/kaggle-notebooks/ML_Models")==True:
    PrintColor(f"\n--> ML_Models already exists\n",color=Fore.RED);
else:
    os.mkdir("/home/jupyter/kaggle-notebooks/ML_Models");
    PrintColor(f"\n-->ML_Models directry has created to store models for inference\n",color=Fore.RED)
# Out:
# --> ML_Models already exists
#
# CPU times: user 962 µs, sys: 0 ns, total: 962 µs
# Wall time: 831 µs

# %% [markdown]
# # Preprocessing

# %%
# %time 

class Preprocessor():
    """
    This class aims to do the below-
    1. Read the datasets
    2. In this case, process the original data
    3. Check information and description
    4. Check unique values and nulls
    5. Collate starting features 
    6. Conjoin train-original data if requested based on Adversarial CV results
    """;
    
    def __init__(self):
        self.train             = pd.read_csv(os.path.join(CFG.path,"train.csv"), index_col = 'id');
        self.test              = pd.read_csv(os.path.join(CFG.path ,"test.csv"), index_col = 'id');
        self.target            = CFG.target ;
        self.original          = pd.read_csv(CFG.orig_path);
        self.conjoin_orig_data = CFG.conjoin_orig_data;
        self.dtl_preproc_req   = CFG.dtl_preproc_req;
        self.test_req          = CFG.test_req;
        
        self.sub_fl   = pd.read_csv(os.path.join(CFG.path, "sample_submission.csv"));
        PrintColor(f"Data shapes - train-test-original = {self.train.shape} {self.test.shape} {self.original.shape}");
        
        for tbl in [self.train, self.original, self.test]:
            tbl.columns = tbl.columns.str.replace(r"\(|\)|\s+","", regex = True);
            tbl['allelectrons_Total'] = tbl['allelectrons_Total'].astype(np.uint16);
        
        PrintColor(f"\nTrain set head", color = Fore.GREEN);
        display(self.train.head(5).style.format(precision = 3));
        PrintColor(f"\nTest set head", color = Fore.GREEN);
        display(self.test.head(5).style.format(precision = 3));
        PrintColor(f"\nOriginal set head", color = Fore.GREEN);
        display(self.original.head(5).style.format(precision = 3));
                 
        # Resetting original data index:-
        self.original.index = range(len(self.original));
        self.original.index+= max(self.test.index) + 1;
        self.original.index.name = 'id';
        
        #  Changing original data column order to match the competition column structure:-
        self.original = self.original.reindex(self.train.columns, axis=1);
              
    def _AddSourceCol(self):
        self.train['Source'] = "Competition";
        self.test['Source']  = "Competition";
        self.original['Source'] = 'Original';
        
        self.strt_ftre = self.test.columns;
        return self;
          
    def _CollateInfoDesc(self):
        if self.dtl_preproc_req == "Y":
            PrintColor(f"\n{'-'*20} Information and description {'-'*20}\n", color = Fore.MAGENTA);

            # Creating dataset information and description:
            for lbl, df in {'Train': self.train, 'Test': self.test, 'Original': self.original}.items():
                PrintColor(f"\n{lbl} description\n");
                display(df.describe(percentiles= [0.05, 0.25, 0.50, 0.75, 0.9, 0.95, 0.99]).\
                        transpose().\
                        drop(columns = ['count'], errors = 'ignore').\
                        drop([CFG.target], axis=0, errors = 'ignore').\
                        style.format(formatter = '{:,.2f}').\
                        background_gradient(cmap = 'Blues')
                       );

                PrintColor(f"\n{lbl} information\n");
                display(df.info());
                collect();
        return self;
    
    def _CollateUnqNull(self):
        
        if self.dtl_preproc_req == "Y":
            # Dislaying the unique values across train-test-original:-
            PrintColor(f"\nUnique and null values\n");
            _ = pd.concat([self.train[self.strt_ftre].nunique(), 
                           self.test[self.strt_ftre].nunique(), 
                           self.original[self.strt_ftre].nunique(),
                           self.train[self.strt_ftre].isna().sum(axis=0),
                           self.test[self.strt_ftre].isna().sum(axis=0),
                           self.original[self.strt_ftre].isna().sum(axis=0)
                          ], 
                          axis=1);
            _.columns = ['Train_Nunq', 'Test_Nunq', 'Original_Nunq', 
                         'Train_Nulls', 'Test_Nulls', 'Original_Nulls'
                        ];

            display(_.T.style.background_gradient(cmap = 'Blues', axis=1).\
                    format(formatter = '{:,.0f}')
                   );
            
        return self;
       
    def DoPreprocessing(self):
        self._AddSourceCol();
        self._CollateInfoDesc();
        self._CollateUnqNull();
        
        return self; 
        
    def ConjoinTrainOrig(self):
        if self.conjoin_orig_data == "Y":
            PrintColor(f"Train shape before conjoining with original = {self.train.shape}");
            train = pd.concat([self.train, self.original], axis=0, ignore_index = True);
            PrintColor(f"Train shape after conjoining with original= {train.shape}");
            
            train = train.drop_duplicates();
            PrintColor(f"Train shape after de-duping = {train.shape}");
            
            train.index = range(len(train));
            train.index.name = 'id';
        
        else:
            PrintColor(f"We are using the competition training data only");
            train = self.train;
        return train;
          
collect();
print();
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 8.11 µs

# %%
# %%time 

pp = Preprocessor();
pp.DoPreprocessing();

if CFG.ensemble_req == "Y":
    sub_fl = pp.sub_fl.copy(deep = True);

print();
collect();
# Out:
# Data shapes - train-test-original = (10407, 12) (6939, 11) (622, 13)
#
# Train set head
# <style type="text/css">
# </style>
# <table id="T_9b4ed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b4ed_level0_col0" class="col_heading level0 col0" >allelectrons_Total</th>
#       <th id="T_9b4ed_level0_col1" class="col_heading level0 col1" >density_Total</th>
#       <th id="T_9b4ed_level0_col2" class="col_heading level0 col2" >allelectrons_Average</th>
#       <th id="T_9b4ed_level0_col3" class="col_heading level0 col3" >val_e_Average</th>
#       <th id="T_9b4ed_level0_col4" class="col_heading level0 col4" >atomicweight_Average</th>
#       <th id="T_9b4ed_level0_col5" class="col_heading level0 col5" >ionenergy_Average</th>
#       <th id="T_9b4ed_level0_col6" class="col_heading level0 col6" >el_neg_chi_Average</th>
#       <th id="T_9b4ed_level0_col7" class="col_heading level0 col7" >R_vdw_element_Average</th>
#       <th id="T_9b4ed_level0_col8" class="col_heading level0 col8" >R_cov_element_Average</th>
#       <th id="T_9b4ed_level0_col9" class="col_heading level0 col9" >zaratio_Average</th>
#       <th id="T_9b4ed_level0_col10" class="col_heading level0 col10" >density_Average</th>
#       <th id="T_9b4ed_level0_col11" class="col_heading level0 col11" >Hardness</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b4ed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9b4ed_row0_col0" class="data row0 col0" >100</td>
#       <td id="T_9b4ed_row0_col1" class="data row0 col1" >0.842</td>
#       <td id="T_9b4ed_row0_col2" class="data row0 col2" >10.000</td>
#       <td id="T_9b4ed_row0_col3" class="data row0 col3" >4.800</td>
#       <td id="T_9b4ed_row0_col4" class="data row0 col4" >20.613</td>
#       <td id="T_9b4ed_row0_col5" class="data row0 col5" >11.088</td>
#       <td id="T_9b4ed_row0_col6" class="data row0 col6" >2.766</td>
#       <td id="T_9b4ed_row0_col7" class="data row0 col7" >1.732</td>
#       <td id="T_9b4ed_row0_col8" class="data row0 col8" >0.860</td>
#       <td id="T_9b4ed_row0_col9" class="data row0 col9" >0.496</td>
#       <td id="T_9b4ed_row0_col10" class="data row0 col10" >0.915</td>
#       <td id="T_9b4ed_row0_col11" class="data row0 col11" >6.000</td>
#     </tr>
#     <tr>
#       <th id="T_9b4ed_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9b4ed_row1_col0" class="data row1 col0" >100</td>
#       <td id="T_9b4ed_row1_col1" class="data row1 col1" >7.558</td>
#       <td id="T_9b4ed_row1_col2" class="data row1 col2" >10.000</td>
#       <td id="T_9b4ed_row1_col3" class="data row1 col3" >4.800</td>
#       <td id="T_9b4ed_row1_col4" class="data row1 col4" >20.299</td>
#       <td id="T_9b4ed_row1_col5" class="data row1 col5" >12.041</td>
#       <td id="T_9b4ed_row1_col6" class="data row1 col6" >2.755</td>
#       <td id="T_9b4ed_row1_col7" class="data row1 col7" >1.631</td>
#       <td id="T_9b4ed_row1_col8" class="data row1 col8" >0.910</td>
#       <td id="T_9b4ed_row1_col9" class="data row1 col9" >0.493</td>
#       <td id="T_9b4ed_row1_col10" class="data row1 col10" >0.718</td>
#       <td id="T_9b4ed_row1_col11" class="data row1 col11" >6.500</td>
#     </tr>
#     <tr>
#       <th id="T_9b4ed_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9b4ed_row2_col0" class="data row2 col0" >76</td>
#       <td id="T_9b4ed_row2_col1" class="data row2 col1" >8.886</td>
#       <td id="T_9b4ed_row2_col2" class="data row2 col2" >15.600</td>
#       <td id="T_9b4ed_row2_col3" class="data row2 col3" >5.600</td>
#       <td id="T_9b4ed_row2_col4" class="data row2 col4" >33.739</td>
#       <td id="T_9b4ed_row2_col5" class="data row2 col5" >12.086</td>
#       <td id="T_9b4ed_row2_col6" class="data row2 col6" >2.828</td>
#       <td id="T_9b4ed_row2_col7" class="data row2 col7" >1.788</td>
#       <td id="T_9b4ed_row2_col8" class="data row2 col8" >0.864</td>
#       <td id="T_9b4ed_row2_col9" class="data row2 col9" >0.481</td>
#       <td id="T_9b4ed_row2_col10" class="data row2 col10" >1.506</td>
#       <td id="T_9b4ed_row2_col11" class="data row2 col11" >2.500</td>
#     </tr>
#     <tr>
#       <th id="T_9b4ed_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9b4ed_row3_col0" class="data row3 col0" >100</td>
#       <td id="T_9b4ed_row3_col1" class="data row3 col1" >8.795</td>
#       <td id="T_9b4ed_row3_col2" class="data row3 col2" >10.000</td>
#       <td id="T_9b4ed_row3_col3" class="data row3 col3" >4.800</td>
#       <td id="T_9b4ed_row3_col4" class="data row3 col4" >20.213</td>
#       <td id="T_9b4ed_row3_col5" class="data row3 col5" >10.948</td>
#       <td id="T_9b4ed_row3_col6" class="data row3 col6" >2.648</td>
#       <td id="T_9b4ed_row3_col7" class="data row3 col7" >1.626</td>
#       <td id="T_9b4ed_row3_col8" class="data row3 col8" >0.936</td>
#       <td id="T_9b4ed_row3_col9" class="data row3 col9" >0.489</td>
#       <td id="T_9b4ed_row3_col10" class="data row3 col10" >0.789</td>
#       <td id="T_9b4ed_row3_col11" class="data row3 col11" >6.000</td>
#     </tr>
#     <tr>
#       <th id="T_9b4ed_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9b4ed_row4_col0" class="data row4 col0" >116</td>
#       <td id="T_9b4ed_row4_col1" class="data row4 col1" >9.578</td>
#       <td id="T_9b4ed_row4_col2" class="data row4 col2" >11.600</td>
#       <td id="T_9b4ed_row4_col3" class="data row4 col3" >4.800</td>
#       <td id="T_9b4ed_row4_col4" class="data row4 col4" >24.988</td>
#       <td id="T_9b4ed_row4_col5" class="data row4 col5" >11.824</td>
#       <td id="T_9b4ed_row4_col6" class="data row4 col6" >2.766</td>
#       <td id="T_9b4ed_row4_col7" class="data row4 col7" >1.682</td>
#       <td id="T_9b4ed_row4_col8" class="data row4 col8" >0.896</td>
#       <td id="T_9b4ed_row4_col9" class="data row4 col9" >0.493</td>
#       <td id="T_9b4ed_row4_col10" class="data row4 col10" >1.865</td>
#       <td id="T_9b4ed_row4_col11" class="data row4 col11" >6.000</td>
#     </tr>
#   </tbody>
# </table>
# Test set head
# <style type="text/css">
# </style>
# <table id="T_d5da8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5da8_level0_col0" class="col_heading level0 col0" >allelectrons_Total</th>
#       <th id="T_d5da8_level0_col1" class="col_heading level0 col1" >density_Total</th>
#       <th id="T_d5da8_level0_col2" class="col_heading level0 col2" >allelectrons_Average</th>
#       <th id="T_d5da8_level0_col3" class="col_heading level0 col3" >val_e_Average</th>
#       <th id="T_d5da8_level0_col4" class="col_heading level0 col4" >atomicweight_Average</th>
#       <th id="T_d5da8_level0_col5" class="col_heading level0 col5" >ionenergy_Average</th>
#       <th id="T_d5da8_level0_col6" class="col_heading level0 col6" >el_neg_chi_Average</th>
#       <th id="T_d5da8_level0_col7" class="col_heading level0 col7" >R_vdw_element_Average</th>
#       <th id="T_d5da8_level0_col8" class="col_heading level0 col8" >R_cov_element_Average</th>
#       <th id="T_d5da8_level0_col9" class="col_heading level0 col9" >zaratio_Average</th>
#       <th id="T_d5da8_level0_col10" class="col_heading level0 col10" >density_Average</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5da8_level0_row0" class="row_heading level0 row0" >10407</th>
#       <td id="T_d5da8_row0_col0" class="data row0 col0" >884</td>
#       <td id="T_d5da8_row0_col1" class="data row0 col1" >121.420</td>
#       <td id="T_d5da8_row0_col2" class="data row0 col2" >35.360</td>
#       <td id="T_d5da8_row0_col3" class="data row0 col3" >5.280</td>
#       <td id="T_d5da8_row0_col4" class="data row0 col4" >82.561</td>
#       <td id="T_d5da8_row0_col5" class="data row0 col5" >9.370</td>
#       <td id="T_d5da8_row0_col6" class="data row0 col6" >2.298</td>
#       <td id="T_d5da8_row0_col7" class="data row0 col7" >1.907</td>
#       <td id="T_d5da8_row0_col8" class="data row0 col8" >1.200</td>
#       <td id="T_d5da8_row0_col9" class="data row0 col9" >0.462</td>
#       <td id="T_d5da8_row0_col10" class="data row0 col10" >1.795</td>
#     </tr>
#     <tr>
#       <th id="T_d5da8_level0_row1" class="row_heading level0 row1" >10408</th>
#       <td id="T_d5da8_row1_col0" class="data row1 col0" >90</td>
#       <td id="T_d5da8_row1_col1" class="data row1 col1" >9.932</td>
#       <td id="T_d5da8_row1_col2" class="data row1 col2" >18.000</td>
#       <td id="T_d5da8_row1_col3" class="data row1 col3" >5.600</td>
#       <td id="T_d5da8_row1_col4" class="data row1 col4" >39.568</td>
#       <td id="T_d5da8_row1_col5" class="data row1 col5" >12.086</td>
#       <td id="T_d5da8_row1_col6" class="data row1 col6" >2.868</td>
#       <td id="T_d5da8_row1_col7" class="data row1 col7" >1.652</td>
#       <td id="T_d5da8_row1_col8" class="data row1 col8" >0.864</td>
#       <td id="T_d5da8_row1_col9" class="data row1 col9" >0.476</td>
#       <td id="T_d5da8_row1_col10" class="data row1 col10" >1.412</td>
#     </tr>
#     <tr>
#       <th id="T_d5da8_level0_row2" class="row_heading level0 row2" >10409</th>
#       <td id="T_d5da8_row2_col0" class="data row2 col0" >116</td>
#       <td id="T_d5da8_row2_col1" class="data row2 col1" >7.768</td>
#       <td id="T_d5da8_row2_col2" class="data row2 col2" >11.600</td>
#       <td id="T_d5da8_row2_col3" class="data row2 col3" >4.800</td>
#       <td id="T_d5da8_row2_col4" class="data row2 col4" >23.232</td>
#       <td id="T_d5da8_row2_col5" class="data row2 col5" >11.024</td>
#       <td id="T_d5da8_row2_col6" class="data row2 col6" >2.644</td>
#       <td id="T_d5da8_row2_col7" class="data row2 col7" >1.794</td>
#       <td id="T_d5da8_row2_col8" class="data row2 col8" >0.960</td>
#       <td id="T_d5da8_row2_col9" class="data row2 col9" >0.500</td>
#       <td id="T_d5da8_row2_col10" class="data row2 col10" >0.788</td>
#     </tr>
#     <tr>
#       <th id="T_d5da8_level0_row3" class="row_heading level0 row3" >10410</th>
#       <td id="T_d5da8_row3_col0" class="data row3 col0" >100</td>
#       <td id="T_d5da8_row3_col1" class="data row3 col1" >9.108</td>
#       <td id="T_d5da8_row3_col2" class="data row3 col2" >10.000</td>
#       <td id="T_d5da8_row3_col3" class="data row3 col3" >4.800</td>
#       <td id="T_d5da8_row3_col4" class="data row3 col4" >20.299</td>
#       <td id="T_d5da8_row3_col5" class="data row3 col5" >12.086</td>
#       <td id="T_d5da8_row3_col6" class="data row3 col6" >2.828</td>
#       <td id="T_d5da8_row3_col7" class="data row3 col7" >1.662</td>
#       <td id="T_d5da8_row3_col8" class="data row3 col8" >0.792</td>
#       <td id="T_d5da8_row3_col9" class="data row3 col9" >0.496</td>
#       <td id="T_d5da8_row3_col10" class="data row3 col10" >1.205</td>
#     </tr>
#     <tr>
#       <th id="T_d5da8_level0_row4" class="row_heading level0 row4" >10411</th>
#       <td id="T_d5da8_row4_col0" class="data row4 col0" >55</td>
#       <td id="T_d5da8_row4_col1" class="data row4 col1" >4.030</td>
#       <td id="T_d5da8_row4_col2" class="data row4 col2" >11.000</td>
#       <td id="T_d5da8_row4_col3" class="data row4 col3" >4.000</td>
#       <td id="T_d5da8_row4_col4" class="data row4 col4" >22.978</td>
#       <td id="T_d5da8_row4_col5" class="data row4 col5" >11.281</td>
#       <td id="T_d5da8_row4_col6" class="data row4 col6" >2.455</td>
#       <td id="T_d5da8_row4_col7" class="data row4 col7" >1.750</td>
#       <td id="T_d5da8_row4_col8" class="data row4 col8" >0.893</td>
#       <td id="T_d5da8_row4_col9" class="data row4 col9" >0.476</td>
#       <td id="T_d5da8_row4_col10" class="data row4 col10" >0.935</td>
#     </tr>
#   </tbody>
# </table>
# Original set head
# <style type="text/css">
# </style>
# <table id="T_43d23">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_43d23_level0_col0" class="col_heading level0 col0" >Unnamed:0</th>
#       <th id="T_43d23_level0_col1" class="col_heading level0 col1" >Hardness</th>
#       <th id="T_43d23_level0_col2" class="col_heading level0 col2" >allelectrons_Total</th>
#       <th id="T_43d23_level0_col3" class="col_heading level0 col3" >density_Total</th>
#       <th id="T_43d23_level0_col4" class="col_heading level0 col4" >allelectrons_Average</th>
#       <th id="T_43d23_level0_col5" class="col_heading level0 col5" >val_e_Average</th>
#       <th id="T_43d23_level0_col6" class="col_heading level0 col6" >atomicweight_Average</th>
#       <th id="T_43d23_level0_col7" class="col_heading level0 col7" >ionenergy_Average</th>
#       <th id="T_43d23_level0_col8" class="col_heading level0 col8" >el_neg_chi_Average</th>
#       <th id="T_43d23_level0_col9" class="col_heading level0 col9" >R_vdw_element_Average</th>
#       <th id="T_43d23_level0_col10" class="col_heading level0 col10" >R_cov_element_Average</th>
#       <th id="T_43d23_level0_col11" class="col_heading level0 col11" >zaratio_Average</th>
#       <th id="T_43d23_level0_col12" class="col_heading level0 col12" >density_Average</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_43d23_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_43d23_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_43d23_row0_col1" class="data row0 col1" >2.300</td>
#       <td id="T_43d23_row0_col2" class="data row0 col2" >110</td>
#       <td id="T_43d23_row0_col3" class="data row0 col3" >23.000</td>
#       <td id="T_43d23_row0_col4" class="data row0 col4" >36.667</td>
#       <td id="T_43d23_row0_col5" class="data row0 col5" >2.667</td>
#       <td id="T_43d23_row0_col6" class="data row0 col6" >82.598</td>
#       <td id="T_43d23_row0_col7" class="data row0 col7" >8.504</td>
#       <td id="T_43d23_row0_col8" class="data row0 col8" >2.147</td>
#       <td id="T_43d23_row0_col9" class="data row0 col9" >2.007</td>
#       <td id="T_43d23_row0_col10" class="data row0 col10" >1.253</td>
#       <td id="T_43d23_row0_col11" class="data row0 col11" >0.457</td>
#       <td id="T_43d23_row0_col12" class="data row0 col12" >7.667</td>
#     </tr>
#     <tr>
#       <th id="T_43d23_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_43d23_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_43d23_row1_col1" class="data row1 col1" >5.500</td>
#       <td id="T_43d23_row1_col2" class="data row1 col2" >406</td>
#       <td id="T_43d23_row1_col3" class="data row1 col3" >30.472</td>
#       <td id="T_43d23_row1_col4" class="data row1 col4" >9.902</td>
#       <td id="T_43d23_row1_col5" class="data row1 col5" >4.683</td>
#       <td id="T_43d23_row1_col6" class="data row1 col6" >19.813</td>
#       <td id="T_43d23_row1_col7" class="data row1 col7" >11.456</td>
#       <td id="T_43d23_row1_col8" class="data row1 col8" >2.700</td>
#       <td id="T_43d23_row1_col9" class="data row1 col9" >1.677</td>
#       <td id="T_43d23_row1_col10" class="data row1 col10" >0.868</td>
#       <td id="T_43d23_row1_col11" class="data row1 col11" >0.523</td>
#       <td id="T_43d23_row1_col12" class="data row1 col12" >0.743</td>
#     </tr>
#     <tr>
#       <th id="T_43d23_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_43d23_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_43d23_row2_col1" class="data row2 col1" >5.500</td>
#       <td id="T_43d23_row2_col2" class="data row2 col2" >406</td>
#       <td id="T_43d23_row2_col3" class="data row2 col3" >30.472</td>
#       <td id="T_43d23_row2_col4" class="data row2 col4" >10.410</td>
#       <td id="T_43d23_row2_col5" class="data row2 col5" >4.923</td>
#       <td id="T_43d23_row2_col6" class="data row2 col6" >20.931</td>
#       <td id="T_43d23_row2_col7" class="data row2 col7" >11.541</td>
#       <td id="T_43d23_row2_col8" class="data row2 col8" >2.754</td>
#       <td id="T_43d23_row2_col9" class="data row2 col9" >1.704</td>
#       <td id="T_43d23_row2_col10" class="data row2 col10" >0.894</td>
#       <td id="T_43d23_row2_col11" class="data row2 col11" >0.497</td>
#       <td id="T_43d23_row2_col12" class="data row2 col12" >0.781</td>
#     </tr>
#     <tr>
#       <th id="T_43d23_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_43d23_row3_col0" class="data row3 col0" >3</td>
#       <td id="T_43d23_row3_col1" class="data row3 col1" >5.500</td>
#       <td id="T_43d23_row3_col2" class="data row3 col2" >476</td>
#       <td id="T_43d23_row3_col3" class="data row3 col3" >61.142</td>
#       <td id="T_43d23_row3_col4" class="data row3 col4" >11.610</td>
#       <td id="T_43d23_row3_col5" class="data row3 col5" >4.683</td>
#       <td id="T_43d23_row3_col6" class="data row3 col6" >23.660</td>
#       <td id="T_43d23_row3_col7" class="data row3 col7" >11.487</td>
#       <td id="T_43d23_row3_col8" class="data row3 col8" >2.764</td>
#       <td id="T_43d23_row3_col9" class="data row3 col9" >1.715</td>
#       <td id="T_43d23_row3_col10" class="data row3 col10" >0.849</td>
#       <td id="T_43d23_row3_col11" class="data row3 col11" >0.519</td>
#       <td id="T_43d23_row3_col12" class="data row3 col12" >1.491</td>
#     </tr>
#     <tr>
#       <th id="T_43d23_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_43d23_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_43d23_row4_col1" class="data row4 col1" >5.500</td>
#       <td id="T_43d23_row4_col2" class="data row4 col2" >476</td>
#       <td id="T_43d23_row4_col3" class="data row4 col3" >61.142</td>
#       <td id="T_43d23_row4_col4" class="data row4 col4" >12.205</td>
#       <td id="T_43d23_row4_col5" class="data row4 col5" >4.923</td>
#       <td id="T_43d23_row4_col6" class="data row4 col6" >24.975</td>
#       <td id="T_43d23_row4_col7" class="data row4 col7" >11.574</td>
#       <td id="T_43d23_row4_col8" class="data row4 col8" >2.820</td>
#       <td id="T_43d23_row4_col9" class="data row4 col9" >1.744</td>
#       <td id="T_43d23_row4_col10" class="data row4 col10" >0.874</td>
#       <td id="T_43d23_row4_col11" class="data row4 col11" >0.494</td>
#       <td id="T_43d23_row4_col12" class="data row4 col12" >1.568</td>
#     </tr>
#   </tbody>
# </table>
# -------------------- Information and description --------------------
#
#
# Train description
# <style type="text/css">
# #T_0c60a_row0_col0, #T_0c60a_row0_col1, #T_0c60a_row0_col3, #T_0c60a_row0_col4, #T_0c60a_row0_col5, #T_0c60a_row0_col6, #T_0c60a_row0_col7, #T_0c60a_row0_col8, #T_0c60a_row0_col9, #T_0c60a_row0_col10 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0c60a_row0_col2, #T_0c60a_row1_col2, #T_0c60a_row2_col2, #T_0c60a_row3_col1, #T_0c60a_row3_col2, #T_0c60a_row3_col10, #T_0c60a_row4_col2, #T_0c60a_row5_col2, #T_0c60a_row5_col10, #T_0c60a_row6_col1, #T_0c60a_row6_col2, #T_0c60a_row6_col9, #T_0c60a_row6_col10, #T_0c60a_row7_col1, #T_0c60a_row7_col2, #T_0c60a_row7_col9, #T_0c60a_row7_col10, #T_0c60a_row8_col0, #T_0c60a_row8_col1, #T_0c60a_row8_col2, #T_0c60a_row8_col6, #T_0c60a_row8_col7, #T_0c60a_row8_col8, #T_0c60a_row8_col9, #T_0c60a_row8_col10, #T_0c60a_row9_col0, #T_0c60a_row9_col1, #T_0c60a_row9_col2, #T_0c60a_row9_col3, #T_0c60a_row9_col4, #T_0c60a_row9_col5, #T_0c60a_row9_col6, #T_0c60a_row9_col7, #T_0c60a_row9_col8, #T_0c60a_row9_col9, #T_0c60a_row9_col10, #T_0c60a_row10_col2, #T_0c60a_row10_col3, #T_0c60a_row10_col10 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0c60a_row1_col0 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_0c60a_row1_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_0c60a_row1_col3, #T_0c60a_row3_col4, #T_0c60a_row5_col7 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_0c60a_row1_col4, #T_0c60a_row1_col5, #T_0c60a_row1_col9 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_0c60a_row1_col6, #T_0c60a_row2_col5 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_0c60a_row1_col7 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_0c60a_row1_col8, #T_0c60a_row2_col0 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_0c60a_row1_col10, #T_0c60a_row3_col5, #T_0c60a_row5_col8 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_0c60a_row2_col1, #T_0c60a_row6_col3 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_0c60a_row2_col3 {
#   background-color: #d0e2f2;
#   color: #000000;
# }
# #T_0c60a_row2_col4 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_0c60a_row2_col6, #T_0c60a_row4_col9 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_0c60a_row2_col7 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_0c60a_row2_col8, #T_0c60a_row5_col4 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_0c60a_row2_col9 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_0c60a_row2_col10, #T_0c60a_row3_col9, #T_0c60a_row5_col1, #T_0c60a_row7_col7, #T_0c60a_row7_col8, #T_0c60a_row8_col3, #T_0c60a_row8_col4, #T_0c60a_row8_col5, #T_0c60a_row10_col4 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_0c60a_row3_col0, #T_0c60a_row3_col6 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_0c60a_row3_col3, #T_0c60a_row5_col6 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_0c60a_row3_col7, #T_0c60a_row6_col5, #T_0c60a_row10_col7, #T_0c60a_row10_col8 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_0c60a_row3_col8, #T_0c60a_row5_col9, #T_0c60a_row6_col0, #T_0c60a_row6_col6, #T_0c60a_row7_col4, #T_0c60a_row10_col6 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_0c60a_row4_col0 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_0c60a_row4_col1 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_0c60a_row4_col3 {
#   background-color: #91c3de;
#   color: #000000;
# }
# #T_0c60a_row4_col4 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_0c60a_row4_col5 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_0c60a_row4_col6 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_0c60a_row4_col7 {
#   background-color: #b0d2e7;
#   color: #000000;
# }
# #T_0c60a_row4_col8 {
#   background-color: #a5cde3;
#   color: #000000;
# }
# #T_0c60a_row4_col10, #T_0c60a_row6_col7, #T_0c60a_row6_col8, #T_0c60a_row7_col0, #T_0c60a_row7_col6, #T_0c60a_row10_col1, #T_0c60a_row10_col5, #T_0c60a_row10_col9 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_0c60a_row5_col0 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_0c60a_row5_col3 {
#   background-color: #c8dcf0;
#   color: #000000;
# }
# #T_0c60a_row5_col5 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_0c60a_row6_col4, #T_0c60a_row7_col3 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_0c60a_row7_col5, #T_0c60a_row10_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# </style>
# <table id="T_0c60a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c60a_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_0c60a_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_0c60a_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_0c60a_level0_col3" class="col_heading level0 col3" >5%</th>
#       <th id="T_0c60a_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_0c60a_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_0c60a_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_0c60a_level0_col7" class="col_heading level0 col7" >90%</th>
#       <th id="T_0c60a_level0_col8" class="col_heading level0 col8" >95%</th>
#       <th id="T_0c60a_level0_col9" class="col_heading level0 col9" >99%</th>
#       <th id="T_0c60a_level0_col10" class="col_heading level0 col10" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c60a_level0_row0" class="row_heading level0 row0" >allelectrons_Total</th>
#       <td id="T_0c60a_row0_col0" class="data row0 col0" >128.05</td>
#       <td id="T_0c60a_row0_col1" class="data row0 col1" >224.12</td>
#       <td id="T_0c60a_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_0c60a_row0_col3" class="data row0 col3" >36.00</td>
#       <td id="T_0c60a_row0_col4" class="data row0 col4" >68.00</td>
#       <td id="T_0c60a_row0_col5" class="data row0 col5" >100.00</td>
#       <td id="T_0c60a_row0_col6" class="data row0 col6" >131.00</td>
#       <td id="T_0c60a_row0_col7" class="data row0 col7" >222.00</td>
#       <td id="T_0c60a_row0_col8" class="data row0 col8" >278.00</td>
#       <td id="T_0c60a_row0_col9" class="data row0 col9" >719.40</td>
#       <td id="T_0c60a_row0_col10" class="data row0 col10" >15,300.00</td>
#     </tr>
#     <tr>
#       <th id="T_0c60a_level0_row1" class="row_heading level0 row1" >density_Total</th>
#       <td id="T_0c60a_row1_col0" class="data row1 col0" >14.49</td>
#       <td id="T_0c60a_row1_col1" class="data row1 col1" >15.97</td>
#       <td id="T_0c60a_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_0c60a_row1_col3" class="data row1 col3" >2.33</td>
#       <td id="T_0c60a_row1_col4" class="data row1 col4" >7.56</td>
#       <td id="T_0c60a_row1_col5" class="data row1 col5" >10.65</td>
#       <td id="T_0c60a_row1_col6" class="data row1 col6" >16.68</td>
#       <td id="T_0c60a_row1_col7" class="data row1 col7" >27.10</td>
#       <td id="T_0c60a_row1_col8" class="data row1 col8" >37.01</td>
#       <td id="T_0c60a_row1_col9" class="data row1 col9" >75.10</td>
#       <td id="T_0c60a_row1_col10" class="data row1 col10" >643.09</td>
#     </tr>
#     <tr>
#       <th id="T_0c60a_level0_row2" class="row_heading level0 row2" >allelectrons_Average</th>
#       <td id="T_0c60a_row2_col0" class="data row2 col0" >17.03</td>
#       <td id="T_0c60a_row2_col1" class="data row2 col1" >10.47</td>
#       <td id="T_0c60a_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_0c60a_row2_col3" class="data row2 col3" >7.50</td>
#       <td id="T_0c60a_row2_col4" class="data row2 col4" >10.00</td>
#       <td id="T_0c60a_row2_col5" class="data row2 col5" >12.60</td>
#       <td id="T_0c60a_row2_col6" class="data row2 col6" >22.00</td>
#       <td id="T_0c60a_row2_col7" class="data row2 col7" >31.33</td>
#       <td id="T_0c60a_row2_col8" class="data row2 col8" >42.00</td>
#       <td id="T_0c60a_row2_col9" class="data row2 col9" >50.00</td>
#       <td id="T_0c60a_row2_col10" class="data row2 col10" >67.00</td>
#     </tr>
#     <tr>
#       <th id="T_0c60a_level0_row3" class="row_heading level0 row3" >val_e_Average</th>
#       <td id="T_0c60a_row3_col0" class="data row3 col0" >4.55</td>
#       <td id
# Train information
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 10407 entries, 0 to 10406
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   allelectrons_Total     10407 non-null  uint16
#  1   density_Total          10407 non-null  float64
#  2   allelectrons_Average   10407 non-null  float64
#  3   val_e_Average          10407 non-null  float64
#  4   atomicweight_Average   10407 non-null  float64
#  5   ionenergy_Average      10407 non-null  float64
#  6   el_neg_chi_Average     10407 non-null  float64
#  7   R_vdw_element_Average  10407 non-null  float64
#  8   R_cov_element_Average  10407 non-null  float64
#  9   zaratio_Average        10407 non-null  float64
#  10  density_Average        10407 non-null  float64
#  11  Hardness               10407 non-null  float64
#  12  Source                 10407 non-null  object
# dtypes: float64(11), object(1), uint16(1)
# memory usage: 1.1+ MB
# None
# Test description
# <style type="text/css">
# #T_8fa03_row0_col0, #T_8fa03_row0_col1, #T_8fa03_row0_col3, #T_8fa03_row0_col4, #T_8fa03_row0_col5, #T_8fa03_row0_col6, #T_8fa03_row0_col7, #T_8fa03_row0_col8, #T_8fa03_row0_col9, #T_8fa03_row0_col10 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8fa03_row0_col2, #T_8fa03_row1_col2, #T_8fa03_row2_col2, #T_8fa03_row3_col1, #T_8fa03_row3_col2, #T_8fa03_row3_col10, #T_8fa03_row4_col2, #T_8fa03_row5_col2, #T_8fa03_row5_col10, #T_8fa03_row6_col1, #T_8fa03_row6_col2, #T_8fa03_row6_col9, #T_8fa03_row6_col10, #T_8fa03_row7_col1, #T_8fa03_row7_col2, #T_8fa03_row7_col9, #T_8fa03_row7_col10, #T_8fa03_row8_col0, #T_8fa03_row8_col1, #T_8fa03_row8_col2, #T_8fa03_row8_col6, #T_8fa03_row8_col7, #T_8fa03_row8_col8, #T_8fa03_row8_col9, #T_8fa03_row8_col10, #T_8fa03_row9_col0, #T_8fa03_row9_col1, #T_8fa03_row9_col2, #T_8fa03_row9_col3, #T_8fa03_row9_col4, #T_8fa03_row9_col5, #T_8fa03_row9_col6, #T_8fa03_row9_col7, #T_8fa03_row9_col8, #T_8fa03_row9_col9, #T_8fa03_row9_col10, #T_8fa03_row10_col2, #T_8fa03_row10_col3, #T_8fa03_row10_col10 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8fa03_row1_col0 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_8fa03_row1_col1 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_8fa03_row1_col3 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_8fa03_row1_col4, #T_8fa03_row1_col5 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_8fa03_row1_col6 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_8fa03_row1_col7, #T_8fa03_row2_col5 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_8fa03_row1_col8, #T_8fa03_row2_col0 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_8fa03_row1_col9 {
#   background-color: #dae8f6;
#   color: #000000;
# }
# #T_8fa03_row1_col10 {
#   background-color: #eaf3fb;
#   color: #000000;
# }
# #T_8fa03_row2_col1, #T_8fa03_row3_col4, #T_8fa03_row5_col7 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_8fa03_row2_col3 {
#   background-color: #cddff1;
#   color: #000000;
# }
# #T_8fa03_row2_col4, #T_8fa03_row2_col7 {
#   background-color: #dbe9f6;
#   color: #000000;
# }
# #T_8fa03_row2_col6 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_8fa03_row2_col8, #T_8fa03_row5_col4 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_8fa03_row2_col9 {
#   background-color: #eaf2fb;
#   color: #000000;
# }
# #T_8fa03_row2_col10, #T_8fa03_row3_col9, #T_8fa03_row5_col1, #T_8fa03_row7_col7, #T_8fa03_row7_col8, #T_8fa03_row8_col4, #T_8fa03_row8_col5, #T_8fa03_row10_col4 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_8fa03_row3_col0, #T_8fa03_row3_col6, #T_8fa03_row7_col3 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_8fa03_row3_col3 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_8fa03_row3_col5, #T_8fa03_row5_col8 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_8fa03_row3_col7, #T_8fa03_row6_col5, #T_8fa03_row10_col7, #T_8fa03_row10_col8 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_8fa03_row3_col8, #T_8fa03_row4_col10, #T_8fa03_row5_col9, #T_8fa03_row6_col0, #T_8fa03_row6_col6, #T_8fa03_row7_col4, #T_8fa03_row10_col6 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_8fa03_row4_col0 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_8fa03_row4_col1 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_8fa03_row4_col3 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_8fa03_row4_col4 {
#   background-color: #b8d5ea;
#   color: #000000;
# }
# #T_8fa03_row4_col5, #T_8fa03_row5_col3 {
#   background-color: #c3daee;
#   color: #000000;
# }
# #T_8fa03_row4_col6 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_8fa03_row4_col7 {
#   background-color: #abd0e6;
#   color: #000000;
# }
# #T_8fa03_row4_col8 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_8fa03_row4_col9 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_8fa03_row5_col0 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_8fa03_row5_col5 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_8fa03_row5_col6 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_8fa03_row6_col3 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_8fa03_row6_col4 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_8fa03_row6_col7, #T_8fa03_row6_col8, #T_8fa03_row7_col0, #T_8fa03_row7_col6, #T_8fa03_row8_col3, #T_8fa03_row10_col1, #T_8fa03_row10_col5, #T_8fa03_row10_col9 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_8fa03_row7_col5, #T_8fa03_row10_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# </style>
# <table id="T_8fa03">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8fa03_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_8fa03_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_8fa03_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_8fa03_level0_col3" class="col_heading level0 col3" >5%</th>
#       <th id="T_8fa03_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_8fa03_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_8fa03_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_8fa03_level0_col7" class="col_heading level0 col7" >90%</th>
#       <th id="T_8fa03_level0_col8" class="col_heading level0 col8" >95%</th>
#       <th id="T_8fa03_level0_col9" class="col_heading level0 col9" >99%</th>
#       <th id="T_8fa03_level0_col10" class="col_heading level0 col10" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8fa03_level0_row0" class="row_heading level0 row0" >allelectrons_Total</th>
#       <td id="T_8fa03_row0_col0" class="data row0 col0" >126.46</td>
#       <td id="T_8fa03_row0_col1" class="data row0 col1" >207.56</td>
#       <td id="T_8fa03_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_8fa03_row0_col3" class="data row0 col3" >33.00</td>
#       <td id="T_8fa03_row0_col4" class="data row0 col4" >68.00</td>
#       <td id="T_8fa03_row0_col5" class="data row0 col5" >100.00</td>
#       <td id="T_8fa03_row0_col6" class="data row0 col6" >128.00</td>
#       <td id="T_8fa03_row0_col7" class="data row0 col7" >220.00</td>
#       <td id="T_8fa03_row0_col8" class="data row0 col8" >278.00</td>
#       <td id="T_8fa03_row0_col9" class="data row0 col9" >710.00</td>
#       <td id="T_8fa03_row0_col10" class="data row0 col10" >10,116.00</td>
#     </tr>
#     <tr>
#       <th id="T_8fa03_level0_row1" class="row_heading level0 row1" >density_Total</th>
#       <td id="T_8fa03_row1_col0" class="data row1 col0" >14.79</td>
#       <td id="T_8fa03_row1_col1" class="data row1 col1" >18.98</td>
#       <td id="T_8fa03_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_8fa03_row1_col3" class="data row1 col3" >2.33</td>
#       <td id="T_8fa03_row1_col4" class="data row1 col4" >7.56</td>
#       <td id="T_8fa03_row1_col5" class="data row1 col5" >10.65</td>
#       <td id="T_8fa03_row1_col6" class="data row1 col6" >16.60</td>
#       <td id="T_8fa03_row1_col7" class="data row1 col7" >27.11</td>
#       <td id="T_8fa03_row1_col8" class="data row1 col8" >37.78</td>
#       <td id="T_8fa03_row1_col9" class="data row1 col9" >105.51</td>
#       <td id="T_8fa03_row1_col10" class="data row1 col10" >643.09</td>
#     </tr>
#     <tr>
#       <th id="T_8fa03_level0_row2" class="row_heading level0 row2" >allelectrons_Average</th>
#       <td id="T_8fa03_row2_col0" class="data row2 col0" >17.41</td>
#       <td id="T_8fa03_row2_col1" class="data row2 col1" >11.00</td>
#       <td id="T_8fa03_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_8fa03_row2_col3" class="data row2 col3" >7.50</td>
#       <td id="T_8fa03_row2_col4" class="data row2 col4" >10.00</td>
#       <td id="T_8fa03_row2_col5" class="data row2 col5" >12.67</td>
#       <td id="T_8fa03_row2_col6" class="data row2 col6" >22.00</td>
#       <td id="T_8fa03_row2_col7" class="data row2 col7" >32.00</td>
#       <td id="T_8fa03_row2_col8" class="data row2 col8" >42.80</td>
#       <td id="T_8fa03_row2_col9" class="data row2 col9" >50.00</td>
#       <td id="T_8fa03_row2_col10" class="data row2 col10" >67.00</td>
#     </tr>
#     <tr>
#       <th id="T
# Test information
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 6939 entries, 10407 to 17345
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   allelectrons_Total     6939 non-null   uint16
#  1   density_Total          6939 non-null   float64
#  2   allelectrons_Average   6939 non-null   float64
#  3   val_e_Average          6939 non-null   float64
#  4   atomicweight_Average   6939 non-null   float64
#  5   ionenergy_Average      6939 non-null   float64
#  6   el_neg_chi_Average     6939 non-null   float64
#  7   R_vdw_element_Average  6939 non-null   float64
#  8   R_cov_element_Average  6939 non-null   float64
#  9   zaratio_Average        6939 non-null   float64
#  10  density_Average        6939 non-null   float64
#  11  Source                 6939 non-null   object
# dtypes: float64(10), object(1), uint16(1)
# memory usage: 664.1+ KB
# None
# Original description
# <style type="text/css">
# #T_9fc96_row0_col0, #T_9fc96_row0_col1, #T_9fc96_row0_col3, #T_9fc96_row0_col4, #T_9fc96_row0_col5, #T_9fc96_row0_col6, #T_9fc96_row0_col7, #T_9fc96_row0_col8, #T_9fc96_row0_col9, #T_9fc96_row0_col10 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9fc96_row0_col2, #T_9fc96_row1_col2, #T_9fc96_row2_col2, #T_9fc96_row3_col1, #T_9fc96_row3_col2, #T_9fc96_row3_col10, #T_9fc96_row4_col2, #T_9fc96_row5_col1, #T_9fc96_row5_col2, #T_9fc96_row5_col10, #T_9fc96_row6_col1, #T_9fc96_row6_col2, #T_9fc96_row6_col8, #T_9fc96_row6_col9, #T_9fc96_row6_col10, #T_9fc96_row7_col0, #T_9fc96_row7_col1, #T_9fc96_row7_col2, #T_9fc96_row7_col6, #T_9fc96_row7_col7, #T_9fc96_row7_col8, #T_9fc96_row7_col9, #T_9fc96_row7_col10, #T_9fc96_row8_col0, #T_9fc96_row8_col1, #T_9fc96_row8_col2, #T_9fc96_row8_col4, #T_9fc96_row8_col5, #T_9fc96_row8_col6, #T_9fc96_row8_col7, #T_9fc96_row8_col8, #T_9fc96_row8_col9, #T_9fc96_row8_col10, #T_9fc96_row9_col0, #T_9fc96_row9_col1, #T_9fc96_row9_col2, #T_9fc96_row9_col3, #T_9fc96_row9_col4, #T_9fc96_row9_col5, #T_9fc96_row9_col6, #T_9fc96_row9_col7, #T_9fc96_row9_col8, #T_9fc96_row9_col9, #T_9fc96_row9_col10, #T_9fc96_row10_col1, #T_9fc96_row10_col2, #T_9fc96_row10_col3, #T_9fc96_row10_col4, #T_9fc96_row10_col5, #T_9fc96_row10_col10 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_9fc96_row1_col0, #T_9fc96_row1_col6 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_9fc96_row1_col1, #T_9fc96_row2_col0, #T_9fc96_row2_col6, #T_9fc96_row6_col3 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_9fc96_row1_col3 {
#   background-color: #e7f1fa;
#   color: #000000;
# }
# #T_9fc96_row1_col4, #T_9fc96_row4_col0 {
#   background-color: #e3eef8;
#   color: #000000;
# }
# #T_9fc96_row1_col5, #T_9fc96_row5_col4 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_9fc96_row1_col7 {
#   background-color: #e4eff9;
#   color: #000000;
# }
# #T_9fc96_row1_col8 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_9fc96_row1_col9, #T_9fc96_row4_col5 {
#   background-color: #e0ecf8;
#   color: #000000;
# }
# #T_9fc96_row1_col10 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_9fc96_row2_col1, #T_9fc96_row3_col6, #T_9fc96_row3_col7, #T_9fc96_row3_col8, #T_9fc96_row4_col10, #T_9fc96_row5_col9, #T_9fc96_row7_col4, #T_9fc96_row10_col7, #T_9fc96_row10_col8 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_9fc96_row2_col3 {
#   background-color: #d9e8f5;
#   color: #000000;
# }
# #T_9fc96_row2_col4, #T_9fc96_row4_col9 {
#   background-color: #e5eff9;
#   color: #000000;
# }
# #T_9fc96_row2_col5, #T_9fc96_row5_col5 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_9fc96_row2_col7 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_9fc96_row2_col8 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_9fc96_row2_col9, #T_9fc96_row3_col4 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_9fc96_row2_col10, #T_9fc96_row3_col9, #T_9fc96_row6_col0, #T_9fc96_row6_col6, #T_9fc96_row6_col7, #T_9fc96_row7_col5, #T_9fc96_row8_col3, #T_9fc96_row10_col0, #T_9fc96_row10_col6, #T_9fc96_row10_col9 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_9fc96_row3_col0, #T_9fc96_row6_col5 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_9fc96_row3_col3 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_9fc96_row3_col5, #T_9fc96_row5_col7, #T_9fc96_row5_col8, #T_9fc96_row6_col4 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_9fc96_row4_col1, #T_9fc96_row5_col6 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_9fc96_row4_col3 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_9fc96_row4_col4 {
#   background-color: #d2e3f3;
#   color: #000000;
# }
# #T_9fc96_row4_col6 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_9fc96_row4_col7 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_9fc96_row4_col8 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_9fc96_row5_col0 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_9fc96_row5_col3 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_9fc96_row7_col3 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# </style>
# <table id="T_9fc96">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9fc96_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_9fc96_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_9fc96_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_9fc96_level0_col3" class="col_heading level0 col3" >5%</th>
#       <th id="T_9fc96_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_9fc96_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_9fc96_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_9fc96_level0_col7" class="col_heading level0 col7" >90%</th>
#       <th id="T_9fc96_level0_col8" class="col_heading level0 col8" >95%</th>
#       <th id="T_9fc96_level0_col9" class="col_heading level0 col9" >99%</th>
#       <th id="T_9fc96_level0_col10" class="col_heading level0 col10" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fc96_level0_row0" class="row_heading level0 row0" >allelectrons_Total</th>
#       <td id="T_9fc96_row0_col0" class="data row0 col0" >312.86</td>
#       <td id="T_9fc96_row0_col1" class="data row0 col1" >853.33</td>
#       <td id="T_9fc96_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_9fc96_row0_col3" class="data row0 col3" >39.05</td>
#       <td id="T_9fc96_row0_col4" class="data row0 col4" >98.25</td>
#       <td id="T_9fc96_row0_col5" class="data row0 col5" >186.50</td>
#       <td id="T_9fc96_row0_col6" class="data row0 col6" >390.00</td>
#       <td id="T_9fc96_row0_col7" class="data row0 col7" >530.80</td>
#       <td id="T_9fc96_row0_col8" class="data row0 col8" >600.95</td>
#       <td id="T_9fc96_row0_col9" class="data row0 col9" >1,256.44</td>
#       <td id="T_9fc96_row0_col10" class="data row0 col10" >15,300.00</td>
#     </tr>
#     <tr>
#       <th id="T_9fc96_level0_row1" class="row_heading level0 row1" >density_Total</th>
#       <td id="T_9fc96_row1_col0" class="data row1 col0" >27.86</td>
#       <td id="T_9fc96_row1_col1" class="data row1 col1" >39.24</td>
#       <td id="T_9fc96_row1_col2" class="data row1 col2" >0.00</td>
#       <td id="T_9fc96_row1_col3" class="data row1 col3" >3.55</td>
#       <td id="T_9fc96_row1_col4" class="data row1 col4" >10.56</td>
#       <td id="T_9fc96_row1_col5" class="data row1 col5" >20.74</td>
#       <td id="T_9fc96_row1_col6" class="data row1 col6" >34.82</td>
#       <td id="T_9fc96_row1_col7" class="data row1 col7" >51.86</td>
#       <td id="T_9fc96_row1_col8" class="data row1 col8" >68.29</td>
#       <td id="T_9fc96_row1_col9" class="data row1 col9" >143.11</td>
#       <td id="T_9fc96_row1_col10" class="data row1 col10" >643.09</td>
#     </tr>
#     <tr>
#       <th id="T_9fc96_level0_row2" class="row_heading level0 row2" >allelectrons_Average</th>
#       <td id="T_9fc96_row2_col0" class="data row2 col0" >14.81</td>
#       <td id="T_9fc96_row2_col1" class="data row2 col1" >9.96</td>
#       <td id="T_9fc96_row2_col2" class="data row2 col2" >0.00</td>
#       <td id="T_9fc96_row2_col3" class="data row2 col3" >6.25</td>
#       <td id="T_9fc96_row2_col4" class="data row2 col4" >9.37</td>
#       <td id="T_9fc96_row2_col5" class="data row2 col5" >10.85</td>
#       <td id="T_9fc96_row2_col6" class="data row2 col6" >17.42</td>
#       <td id="T_9fc96_row2_col7" class="data row2 col7" >28.17</td>
#       <td id="T_9fc96_row2_col8" class="data row2 col8" >36.00</td>
#       <td id="T_9fc96_row2_col9" class="data row2 col9" >49.79</td>
#       <td id="T_9fc96_row2_col10" class="data row2 col10" >67.00</td>
#     </tr>
#     <tr>
#       <th id="T_9fc96_level0_row3" class="row_heading level0 row3" >val_e_Average</th>
#       <td id="T_9fc96_row3_col0" class="data row3 col0" >4.42</td>
#       <td id="T_9fc96_row3_col1" class="data row3 col1" >0.81</td>
#       <td id="T_9fc96_row3_col2" class="data row3 col2" >0.00</td>
#       <td id="T_9fc96_row3_col3" class="data row3 col3" >3.26</td>
#       <td id="T_9fc96_row3_col4" class="data row3 col4" >4.
# Original information
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 622 entries, 17346 to 17967
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   allelectrons_Total     622 non-null    uint16
#  1   density_Total          622 non-null    float64
#  2   allelectrons_Average   622 non-null    float64
#  3   val_e_Average          622 non-null    float64
#  4   atomicweight_Average   622 non-null    float64
#  5   ionenergy_Average      622 non-null    float64
#  6   el_neg_chi_Average     622 non-null    float64
#  7   R_vdw_element_Average  622 non-null    float64
#  8   R_cov_element_Average  622 non-null    float64
#  9   zaratio_Average        622 non-null    float64
#  10  density_Average        622 non-null    float64
#  11  Hardness               622 non-null    float64
#  12  Source                 622 non-null    object
# dtypes: float64(11), object(1), uint16(1)
# memory usage: 59.7+ KB
# None
# Unique and null values
# <style type="text/css">
# #T_b47e5_row0_col0 {
#   background-color: #bfd8ed;
#   color: #000000;
# }
# #T_b47e5_row0_col1, #T_b47e5_row1_col1, #T_b47e5_row2_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_b47e5_row0_col2 {
#   background-color: #539ecd;
#   color: #f1f1f1;
# }
# #T_b47e5_row0_col3 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_b47e5_row0_col4, #T_b47e5_row1_col5 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_b47e5_row0_col5 {
#   background-color: #135fa7;
#   color: #f1f1f1;
# }
# #T_b47e5_row0_col6 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_b47e5_row0_col7 {
#   background-color: #3686c0;
#   color: #f1f1f1;
# }
# #T_b47e5_row0_col8 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_b47e5_row0_col9 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_b47e5_row0_col10 {
#   background-color: #5ca4d0;
#   color: #f1f1f1;
# }
# #T_b47e5_row0_col11, #T_b47e5_row1_col11, #T_b47e5_row2_col11, #T_b47e5_row3_col0, #T_b47e5_row3_col1, #T_b47e5_row3_col2, #T_b47e5_row3_col3, #T_b47e5_row3_col4, #T_b47e5_row3_col5, #T_b47e5_row3_col6, #T_b47e5_row3_col7, #T_b47e5_row3_col8, #T_b47e5_row3_col9, #T_b47e5_row3_col10, #T_b47e5_row3_col11, #T_b47e5_row4_col0, #T_b47e5_row4_col1, #T_b47e5_row4_col2, #T_b47e5_row4_col3, #T_b47e5_row4_col4, #T_b47e5_row4_col5, #T_b47e5_row4_col6, #T_b47e5_row4_col7, #T_b47e5_row4_col8, #T_b47e5_row4_col9, #T_b47e5_row4_col10, #T_b47e5_row4_col11, #T_b47e5_row5_col0, #T_b47e5_row5_col1, #T_b47e5_row5_col2, #T_b47e5_row5_col3, #T_b47e5_row5_col4, #T_b47e5_row5_col5, #T_b47e5_row5_col6, #T_b47e5_row5_col7, #T_b47e5_row5_col8, #T_b47e5_row5_col9, #T_b47e5_row5_col10, #T_b47e5_row5_col11 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b47e5_row1_col0 {
#   background-color: #bdd7ec;
#   color: #000000;
# }
# #T_b47e5_row1_col2 {
#   background-color: #549fcd;
#   color: #f1f1f1;
# }
# #T_b47e5_row1_col3 {
#   background-color: #cfe1f2;
#   color: #000000;
# }
# #T_b47e5_row1_col4 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_b47e5_row1_col6 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_b47e5_row1_col7 {
#   background-color: #3181bd;
#   color: #f1f1f1;
# }
# #T_b47e5_row1_col8 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_b47e5_row1_col9 {
#   background-color: #2676b8;
#   color: #f1f1f1;
# }
# #T_b47e5_row1_col10 {
#   background-color: #3888c1;
#   color: #f1f1f1;
# }
# #T_b47e5_row2_col0 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_b47e5_row2_col2 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_b47e5_row2_col3 {
#   background-color: #aed1e7;
#   color: #000000;
# }
# #T_b47e5_row2_col4, #T_b47e5_row2_col5 {
#   background-color: #083370;
#   color: #f1f1f1;
# }
# #T_b47e5_row2_col6 {
#   background-color: #08478d;
#   color: #f1f1f1;
# }
# #T_b47e5_row2_col7 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_b47e5_row2_col8 {
#   background-color: #105ba4;
#   color: #f1f1f1;
# }
# #T_b47e5_row2_col9, #T_b47e5_row2_col10 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b47e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b47e5_level0_col0" class="col_heading level0 col0" >allelectrons_Total</th>
#       <th id="T_b47e5_level0_col1" class="col_heading level0 col1" >density_Total</th>
#       <th id="T_b47e5_level0_col2" class="col_heading level0 col2" >allelectrons_Average</th>
#       <th id="T_b47e5_level0_col3" class="col_heading level0 col3" >val_e_Average</th>
#       <th id="T_b47e5_level0_col4" class="col_heading level0 col4" >atomicweight_Average</th>
#       <th id="T_b47e5_level0_col5" class="col_heading level0 col5" >ionenergy_Average</th>
#       <th id="T_b47e5_level0_col6" class="col_heading level0 col6" >el_neg_chi_Average</th>
#       <th id="T_b47e5_level0_col7" class="col_heading level0 col7" >R_vdw_element_Average</th>
#       <th id="T_b47e5_level0_col8" class="col_heading level0 col8" >R_cov_element_Average</th>
#       <th id="T_b47e5_level0_col9" class="col_heading level0 col9" >zaratio_Average</th>
#       <th id="T_b47e5_level0_col10" class="col_heading level0 col10" >density_Average</th>
#       <th id="T_b47e5_level0_col11" class="col_heading level0 col11" >Source</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b47e5_level0_row0" class="row_heading level0 row0" >Train_Nunq</th>
#       <td id="T_b47e5_row0_col0" class="data row0 col0" >301</td>
#       <td id="T_b47e5_row0_col1" class="data row0 col1" >1,099</td>
#       <td id="T_b47e5_row0_col2" class="data row0 col2" >629</td>
#       <td id="T_b47e5_row0_col3" class="data row0 col3" >205</td>
#       <td id="T_b47e5_row0_col4" class="data row0 col4" >849</td>
#       <td id="T_b47e5_row0_col5" class="data row0 col5" >898</td>
#       <td id="T_b47e5_row0_col6" class="data row0 col6" >745</td>
#       <td id="T_b47e5_row0_col7" class="data row0 col7" >737</td>
#       <td id="T_b47e5_row0_col8" class="data row0 col8" >698</td>
#       <td id="T_b47e5_row0_col9" class="data row0 col9" >815</td>
#       <td id="T_b47e5_row0_col10" class="data row0 col10" >599</td>
#       <td id="T_b47e5_row0_col11" class="data row0 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b47e5_level0_row1" class="row_heading level0 row1" >Test_Nunq</th>
#       <td id="T_b47e5_row1_col0" class="data row1 col0" >253</td>
#       <td id="T_b47e5_row1_col1" class="data row1 col1" >904</td>
#       <td id="T_b47e5_row1_col2" class="data row1 col2" >514</td>
#       <td id="T_b47e5_row1_col3" class="data row1 col3" >185</td>
#       <td id="T_b47e5_row1_col4" class="data row1 col4" >728</td>
#       <td id="T_b47e5_row1_col5" class="data row1 col5" >699</td>
#       <td id="T_b47e5_row1_col6" class="data row1 col6" >643</td>
#       <td id="T_b47e5_row1_col7" class="data row1 col7" >622</td>
#       <td id="T_b47e5_row1_col8" class="data row1 col8" >592</td>
#       <td id="T_b47e5_row1_col9" class="data row1 col9" >660</td>
#       <td id="T_b47e5_row1_col10" class="data row1 col10" >598</td>
#       <td id="T_b47e5_row1_col11" class="data row1 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b47e5_level0_row2" class="row_heading level0 row2" >Original_Nunq</th>
#       <td id="T_b47e5_row2_col0" class="data row2 col0" >308</td>
#       <td id="T_b47e5_row2_col1" class="data row2 col1" >560</td>
#       <td id="T_b47e5_row2_col2" class="data row2 col2" >436</td>
#       <td id="T_b47e5_row2_col3" class="data row2 col3" >183</td>
#       <td id="T_b47e5_row2_col4" class="data row2 col4" >553</td>
#       <td id="T_b47e5_row2_col5" class="data row2 col5" >552</td>
#       <td id="T_b47e5_row2_col6" class="data row2 col6" >510</td>
#       <td id="T_b47e5_row2_col7" class="data row2 col7" >505</td>
#       <td id="T_b47e5_row2_col8" class="data row2 col8" >467</td>
#       <td id="T_b47e5_row2_col9" class="data row2 col9" >554</td>
#       <td id="T_b47e5_row2_col10" class="data row2 col10" >554</td>
#       <td id="T_b47e5_row2_col11" class="data row2 col11" >1</td>
#     </tr>
#     <tr>
#       <th id="T_b47e5_level0_row3" class="row_heading level0 row3" >Train_Nulls</th>
#       <td id="T_b47e5_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_b47e5_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_b47e5_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_b47e5_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_b47e5_row3_col4" class="data row3 col4" >0</td>
#       <td id="T_b47e5_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_b47e5_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_b47e5_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_b47e5_row3_col8" class="data row3 col8" >0</td>
#       <td id="T_b47e5_row3_col9" class="data row3 col9" >0</td>
#       <td id="T_b47e5_row3_col10" class="data row3 col10" >0</td>
#       <td id="T_b47e5_row3_col11" class="data row3 col11" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b47e5_level0_row4" class="row_heading level0 row4" >Test_Nulls</th>
#       <td id="T_b47e5_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_b47e5_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_b47e5_row4_col2" class="data row4 col2" >0</td>
# CPU times: user 1.15 s, sys: 25.9 ms, total: 1.17 s
# Wall time: 1.22 s

# %% [markdown]
# # Inferences
#
# 1. We have numeirical columns.
# 2. Orginal Dataset have no nulls.
# 3. The dataset is quite small, building a CV is difficult

# %% [markdown]
# # Adverserial CV

# %%
# %%time

# Perform adverserial cv between 2 specified datasets
def Do_AdvCV(df1:pd.DataFrame,df2:pd.DataFrame,source1:str,source2:str):
    """
    This function perform adverserial cv between 2 provided datasets
    """
    
    # Adverserial CV per column
    ftre=pp.test.select_dtypes(include=np.number).\
    drop(columns=['id','Source'],errors='ignore').columns;
    adv_cv={};
    
    for col in ftre:
        shuffle_state=np.random.randint(low=10,high=100,size=1);
        full_df=\
        pd.concat([df1[[col]].assign(Source=source1),
                   df2[[col]].assign(Source=source2)],
                  axis=0,
                  ignore_index=True).\
        sample(frac=1.00,random_state=shuffle_state);
        
        full_df=full_df.assign(Source_Nb=full_df['Source'].eq(source2).astype(np.int8));
        
        # checking for adverserial cv
        model=LGBMClassifier(random_state=CFG.state,
                             max_depth=6,
                             learning_rate=0.05);
        cv=all_cv['SKF'];
        score=np.mean(cross_val_score(model,
                                      full_df[[col]],
                                      full_df.Source_Nb,
                                      scorings='roc_auc',
                                      cv=cv)
                     );
        adv_cv.update({col:round(score,4)});
        collect();
        
    del ftre;
    colect();
    
    fig,ax=plt.subplots(1,1,figsize=(12,5));
    pd.Series(adv_cv).plot.bar(color='tab:blue',ax=ax);
    ax.axhline(y=0.60,color='red',linewidth=2.75);
    ax.grid(**CFG.grid_specs);
    plt.yticks(np.arange(0.0, 0.81, 0.05));
    plt.show();
    
# Implementing the adverserial cv
if CFG.adv_cv_req=="Y":
    PrintColor(f"\n---------- Adversarial CV - Train vs Original ----------\n", 
               color = Fore.MAGENTA);
    Do_AdvCV(df1=pp.train,df2=pp.original,scource1="Train",source2="Original");
    
    PrintColor(f"\n---------- Adversarial CV - Train vs Test ----------\n", 
               color = Fore.MAGENTA);
    Do_AdvCV(df1=pp.train,df2=pp.test,scource1="Train",source2="Test");
    
    PrintColor(f"\n---------- Adversarial CV - Original vs Test ----------\n", 
               color = Fore.MAGENTA);
    Do_AdvCV(df1=pp.original,df2=pp.test,scource1="Original",source2="Test");   
    
if CFG.adv_cv_req=="N":
    PrintColor(f"\nAdverserial CV is not needed",color=Fore.RED);

collect();
print();
# Out:
# Adverserial CV is not needed
#
# CPU times: user 198 ms, sys: 310 µs, total: 198 ms
# Wall time: 196 ms

# %%
# %%time 

print();
train, test, strt_ftre = pp.ConjoinTrainOrig(), pp.test.copy(deep = True), deepcopy(pp.strt_ftre);
cat_cols  = [];
cont_cols = [col for col in pp.strt_ftre if col not in cat_cols + [CFG.target, "Source"]];

if CFG.drop_nulls == "Y":
    train = train.dropna();
else: 
    pass;

PrintColor(f"\nCategory columns\n");
display(cat_cols);
PrintColor(f"\nContinuous columns\n");
display(np.array(cont_cols));
PrintColor(f"\nAll columns\n");
display(strt_ftre);

print();
collect();
# Out:
# Train shape before conjoining with original = (10407, 13)
# Train shape after conjoining with original= (11029, 13)
# Train shape after de-duping = (11006, 13)
#
# Category columns
# []
# Continuous columns
# array(['allelectrons_Total', 'density_Total', 'allelectrons_Average',
#        'val_e_Average', 'atomicweight_Average', 'ionenergy_Average',
#        'el_neg_chi_Average', 'R_vdw_element_Average',
#        'R_cov_element_Average', 'zaratio_Average', 'density_Average'],
#       dtype='<U21')
# All columns
# Index(['allelectrons_Total', 'density_Total', 'allelectrons_Average',
#        'val_e_Average', 'atomicweight_Average', 'ionenergy_Average',
#        'el_neg_chi_Average', 'R_vdw_element_Average', 'R_cov_element_Average',
#        'zaratio_Average', 'density_Average', 'Source'],
#       dtype='object')
# CPU times: user 221 ms, sys: 8.17 ms, total: 229 ms
# Wall time: 224 ms

# %% [markdown]
# # Inferences
#
# 1. Train test belong to same distributions, we can perhaps rely on cv score
# 2. We need to further check the train-original distribution further, adverserial validation results indicate that we cannot use the original dataset based on a couple of features

# %% [markdown]
# <a id="5"></a>
# # <div style= "font-family: Cambria; font-weight:bold; letter-spacing: 0px; color:black; font-size:120%; text-align:left;padding:3.0px; background: #cceeff; border-bottom: 2px solid #004466" > VISUALS AND EDA <br><div>

# %% [markdown]
# ## Target Plot

# %%
# %%time
if CFG.ftre_plots_req=="Y":
    fig,axes=plt.subplots(1,2,figsize=(20,5),shey=True,gridspec_kw={'wspace':0.35});
    
    for i, df in tqdm(enumerate([pp.train,pp.original]),"Target plot -->"):
        ax=axes[i];
        a=df[CFG.target].value_counts(normalize=True);
        a.sort_index().plot.bar(color='#3377ff',ax=ax);
        df_name='Train' if i==0 else "Original"
        _=ax.set_title(f"\n{df_name} data\n",CFG.title_specs);
        
    plt.tight_layout();
    plt.show();
    
print();
collect();
# Out:
# CPU times: user 202 ms, sys: 0 ns, total: 202 ms
# Wall time: 199 ms

# %% [markdown]
# ## Continuous column plots

# %%
# %%time
if CFG.ftre_plots_req=="Y":
    df=pd.concat([pp.train[cont_cols].assign(Source="Train"),
                  pp.test[cont_cols].assign(Source="Test"),
                  pp.original[cont_cols].assign(Source="Original")],
                 axis=0,
                 ignore_index=True);
    fig,axes=plt.subplots(len(cont_cols),
                          4,
                          fig_size=(16,len(cont_cols)*4.2),
                          gridspec_kw= {'hspace': 0.35, 'wspace': 0.3, 'width_ratios': [0.80, 0.20, 0.20, 0.20]});
    for i,col in enumerate(cont_cols):
        ax=axes[i,0];
        sns.kdeplot(data=df[[col,'Source']],
                    x=col,
                    hue="Source",
                    palatte=['#0039e6', '#ff5500', '#00b300'],
                    ax=ax,
                    linewidth=2.1);
        ax.set_title(f"\n{col}",**CFG.title_specs);
        ax.grid(**CFG.grid_specs);
        ax.set(xlabel='',ylabel='');
        
        ax=axes[i,1];
        sns.boxplot(data=df.loc[df.Source=="Train",[col]],
                    y=col,
                    width=0.25,
                    color='#33ccff',
                    saturation=0.90,
                    linewidth=0.90,
                    fliersize=2.25,
                    ax=ax);
        ax.set(xlabel='',ylabel='');
        ax.set_title(f"Train",**CFG.title_specs);
        
        ax = axes[i,2];
        sns.boxplot(data = df.loc[df.Source == 'Test', [col]], y = col, width = 0.25, fliersize= 2.25,
                    color = '#80ffff', saturation = 0.6, linewidth = 0.90, 
                    ax = ax); 
        ax.set(xlabel = '', ylabel = '');
        ax.set_title(f"Test", **CFG.title_specs);
        
        ax = axes[i,3];
        sns.boxplot(data = df.loc[df.Source == 'Original', [col]], y = col, width = 0.25, fliersize= 2.25,
                    color = '#99ddff', saturation = 0.6, linewidth = 0.90, 
                    ax = ax); 
        ax.set(xlabel = '', ylabel = '');
        ax.set_title(f"Original", **CFG.title_specs);
              
    plt.suptitle(f"\nDistribution analysis- continuous columns\n", **CFG.title_specs, 
                 y = 0.905, x = 0.50
                );
    plt.tight_layout();
    plt.show();
    
print();
collect();
# Out:
# CPU times: user 199 ms, sys: 257 µs, total: 199 ms
# Wall time: 198 ms

# %%
# %%time

# calculating skewness across columns
skew_df=pd.DataFrame(index=strt_ftre[0:-1]);
for col,df in {"Train":pp.train,"Test":pp.test,"Original":pp.original}.items():
    skew_df=pd.concat([skew_df,df.drop(columns=[CFG.target,"Source","id"],errors='ignore').skew()],
                      axis=1).rename({0:col},axis=1);
PrintColor(f"\nSkewness across independent features\n");
display(skew_df.T.style.format(precision=2).background_gradient("Pastel2"));

del skew_df;
collect();
print();
# Out:
# Skewness across independent features
# <style type="text/css">
# #T_2a131_row0_col0, #T_2a131_row0_col9, #T_2a131_row1_col1, #T_2a131_row1_col3, #T_2a131_row1_col5, #T_2a131_row1_col6, #T_2a131_row1_col8, #T_2a131_row2_col2, #T_2a131_row2_col4, #T_2a131_row2_col7, #T_2a131_row2_col10 {
#   background-color: #cccccc;
#   color: #000000;
# }
# #T_2a131_row0_col1, #T_2a131_row0_col2, #T_2a131_row0_col4, #T_2a131_row0_col7, #T_2a131_row1_col2, #T_2a131_row1_col4, #T_2a131_row1_col10, #T_2a131_row2_col0, #T_2a131_row2_col1, #T_2a131_row2_col3, #T_2a131_row2_col5, #T_2a131_row2_col6, #T_2a131_row2_col8, #T_2a131_row2_col9 {
#   background-color: #b3e2cd;
#   color: #000000;
# }
# #T_2a131_row0_col3, #T_2a131_row0_col5 {
#   background-color: #fff2ae;
#   color: #000000;
# }
# #T_2a131_row0_col6, #T_2a131_row0_col8, #T_2a131_row1_col0 {
#   background-color: #f1e2cc;
#   color: #000000;
# }
# #T_2a131_row0_col10 {
#   background-color: #fdcdac;
#   color: #000000;
# }
# #T_2a131_row1_col7, #T_2a131_row1_col9 {
#   background-color: #cbd5e8;
#   color: #000000;
# }
# </style>
# <table id="T_2a131">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a131_level0_col0" class="col_heading level0 col0" >allelectrons_Total</th>
#       <th id="T_2a131_level0_col1" class="col_heading level0 col1" >density_Total</th>
#       <th id="T_2a131_level0_col2" class="col_heading level0 col2" >allelectrons_Average</th>
#       <th id="T_2a131_level0_col3" class="col_heading level0 col3" >val_e_Average</th>
#       <th id="T_2a131_level0_col4" class="col_heading level0 col4" >atomicweight_Average</th>
#       <th id="T_2a131_level0_col5" class="col_heading level0 col5" >ionenergy_Average</th>
#       <th id="T_2a131_level0_col6" class="col_heading level0 col6" >el_neg_chi_Average</th>
#       <th id="T_2a131_level0_col7" class="col_heading level0 col7" >R_vdw_element_Average</th>
#       <th id="T_2a131_level0_col8" class="col_heading level0 col8" >R_cov_element_Average</th>
#       <th id="T_2a131_level0_col9" class="col_heading level0 col9" >zaratio_Average</th>
#       <th id="T_2a131_level0_col10" class="col_heading level0 col10" >density_Average</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a131_level0_row0" class="row_heading level0 row0" >Train</th>
#       <td id="T_2a131_row0_col0" class="data row0 col0" >39.93</td>
#       <td id="T_2a131_row0_col1" class="data row0 col1" >9.76</td>
#       <td id="T_2a131_row0_col2" class="data row0 col2" >1.66</td>
#       <td id="T_2a131_row0_col3" class="data row0 col3" >-2.35</td>
#       <td id="T_2a131_row0_col4" class="data row0 col4" >1.80</td>
#       <td id="T_2a131_row0_col5" class="data row0 col5" >-3.55</td>
#       <td id="T_2a131_row0_col6" class="data row0 col6" >-3.47</td>
#       <td id="T_2a131_row0_col7" class="data row0 col7" >-4.67</td>
#       <td id="T_2a131_row0_col8" class="data row0 col8" >-0.54</td>
#       <td id="T_2a131_row0_col9" class="data row0 col9" >-1.32</td>
#       <td id="T_2a131_row0_col10" class="data row0 col10" >1.66</td>
#     </tr>
#     <tr>
#       <th id="T_2a131_level0_row1" class="row_heading level0 row1" >Test</th>
#       <td id="T_2a131_row1_col0" class="data row1 col0" >33.39</td>
#       <td id="T_2a131_row1_col1" class="data row1 col1" >12.68</td>
#       <td id="T_2a131_row1_col2" class="data row1 col2" >1.68</td>
#       <td id="T_2a131_row1_col3" class="data row1 col3" >-2.13</td>
#       <td id="T_2a131_row1_col4" class="data row1 col4" >1.81</td>
#       <td id="T_2a131_row1_col5" class="data row1 col5" >-3.31</td>
#       <td id="T_2a131_row1_col6" class="data row1 col6" >-3.22</td>
#       <td id="T_2a131_row1_col7" class="data row1 col7" >-4.59</td>
#       <td id="T_2a131_row1_col8" class="data row1 col8" >-0.48</td>
#       <td id="T_2a131_row1_col9" class="data row1 col9" >-1.66</td>
#       <td id="T_2a131_row1_col10" class="data row1 col10" >1.61</td>
#     </tr>
#     <tr>
#       <th id="T_2a131_level0_row2" class="row_heading level0 row2" >Original</th>
#       <td id="T_2a131_row2_col0" class="data row2 col0" >13.55</td>
#       <td id="T_2a131_row2_col1" class="data row2 col1" >9.67</td>
#       <td id="T_2a131_row2_col2" class="data row2 col2" >2.02</td>
#       <td id="T_2a131_row2_col3" class="data row2 col3" >-2.72</td>
#       <td id="T_2a131_row2_col4" class="data row2 col4" >2.17</td>
#       <td id="T_2a131_row2_col5" class="data row2 col5" >-4.20</td>
#       <td id="T_2a131_row2_col6" class="data row2 col6" >-4.58</td>
#       <td id="T_2a131_row2_col7" class="data row2 col7" >-4.36</td>
#       <td id="T_2a131_row2_col8" class="data row2 col8" >-0.94</td>
#       <td id="T_2a131_row2_col9" class="data row2 col9" >-1.86</td>
#       <td id="T_2a131_row2_col10" class="data row2 col10" >1.80</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 230 ms, sys: 117 µs, total: 230 ms
# Wall time: 225 ms

# %% [markdown]
# ## Category column plots

# %%
# %%time

if CFG.ftre_plots_req=="Y" and cat_cols!=[]:
    fig,axes=plt.subplots(len(cat_cols),3,fig_size=(20,len(cat_cols)*4.5),gridspec_kw={'wspace':0.25,'hspace':0.3});
    
    for i, col in enumerate(cat_cols):
        ax=axes[i,0]; # ith row and 0th column
        a=pp.train[col].value_counts(normalize=True);
        a.sort_index().plot.barh(ax=ax,color='#007399');
        ax.set_title(f"{col}_train",**CFG.title_specs);
        ax.set_xticks(np.arange(0.0,0.9,0.05),
                      labels=np.round(np.arange(0.0,0.9,0.05),2),
                      rotation=90);
        ax.set(xlabel='',ylabel='');
        del a;
        
        ax = axes[i, 1];
        a = pp.test[col].value_counts(normalize = True);
        a.sort_index().plot.barh(ax = ax, color = '#0088cc');
        ax.set_title(f"{col}_Test", **CFG.title_specs);
        ax.set_xticks(np.arange(0.0, 0.9, 0.05), 
                      labels = np.round(np.arange(0.0, 0.9, 0.05),2), 
                      rotation = 90
                     );
        ax.set(xlabel = '', ylabel = '');
        del a;
        
        ax = axes[i, 2];
        a = pp.original[col].value_counts(normalize = True);
        a.sort_index().plot.barh(ax = ax, color = '#0047b3');
        ax.set_title(f"{col}_Original", **CFG.title_specs);
        ax.set_xticks(np.arange(0.0, 0.9, 0.05), 
                      labels = np.round(np.arange(0.0, 0.9, 0.05),2), 
                      rotation = 90
                     );
        ax.set(xlabel = '', ylabel = '');
        del a;  
        
    plt.suptitle(f"Category column plots",**CFG.title_specs, y=0.90);
    plt.tight_layout();
    plt.show();
    
print();
collect();
# Out:
# CPU times: user 205 ms, sys: 0 ns, total: 205 ms
# Wall time: 203 ms

# %% [markdown]
# ## Feature interaction and Univariate relations

# %%
# %%time

def MakeCorrPlot(df:pd.DataFrame,data_label:str,figsize=(30,9)):
    """
    This function will create a correlation plot for given data
    """
    
    fig,axes=plt.subplots(1,2,figsize=figsize,gridspec_kw={'hspave':0.2,'wspace':0.1},sharey=True);
    
    for i,method in enumerate(['pearson','spearman']):
        corr=df.drop(columns=['id','Source'],errors='ignore').corr(method=method);
        ax=axes[i];
        sns.heatmap(data=corr,
                    fmt='.2f',
                    cmap="Blues",
                    annot_kws={'fontweight':'bold','fontsize':6.75},
                    linewidth=1.5,
                    linecolor='white',
                    cbar=False,
                    mask=np.triu(np.ones_like(corr)),
                    ax=ax);
        ax.set_title(f"\n{method.capitalize()} correlation- {data_label}\n",**CFG.title_specs);
    collect();
    print();
    
# Implementing correlation analysis
if CFG.ftre_imp_req=="Y":
    for lbl,df in {'Train':pp.train,
                   'Test':pp.test,
                   'Original':pp.original}.items():
        MakeCorrPlot(df=df,data_label=lbl,figsize=(22,6.5));
        
print();
collect();
# Out:
# CPU times: user 199 ms, sys: 0 ns, total: 199 ms
# Wall time: 198 ms

# %% [markdown]
# ## Inferences
#
# 1. Feature are positively and negatively skewd and all are non negative. Feature transforms may be useful for non-tree models
# 2. Outlier treatment could be considered as an option considering outlier across all columns in the data
# 3. Higher correlation between quite a few columns may necessitate methods like PCA

# %% [markdown]
# ## Data Transforms

# %% [markdown]
# This section aims at creating secondary features, scaling if necessary, conjoining the competition training and original data.

# %%
# %%time 

# Data transforms:-
class Xformer(TransformerMixin, BaseEstimator):
    """
    This class adds secondary features to the existing data using simple interactions
    """;
    
    def __init__(self): 
        pass
    
    def fit(self, X, y= None, **params):
        return self;
    
    @staticmethod
    def _reduce_mem(df: pd.DataFrame):
        "This method reduces memory for numeric columns in the dataframe";
        
        numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
        start_mem = df.memory_usage().sum() / 1024**2;
        
        for col in df.columns:
            col_type = df[col].dtypes
            
            if col_type in numerics:
                c_min = df[col].min();
                c_max = df[col].max();

                if "int" in str(col_type)[:3]:
                    if c_min >= np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                        df[col] = df[col].astype(np.int8)
                    elif c_min >= np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                        df[col] = df[col].astype(np.int16)
                    elif c_min >= np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                        df[col] = df[col].astype(np.int32)
                    elif c_min >= np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                        df[col] = df[col].astype(np.int64)  
                else:
                    if c_min >= np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                        df[col] = df[col].astype(np.float16)
                    if c_min >= np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                        df[col] = df[col].astype(np.float32)
                    else:
                        df[col] = df[col].astype(np.float64)  

        end_mem = df.memory_usage().sum() / 1024**2
    
        PrintColor(f"Start - end memory:- {start_mem:5.2f} - {end_mem:5.2f} Mb");
        return df;
    
    def transform(self, X, y= None, **params):
        """
        This method adds secondary features to the existing data
        """;
        
        df    = X.copy(); 
        self.op_cols = df.columns;
        df = self._reduce_mem(df);
        return df;
    
    def get_feature_names_in(self, X, y=None, **params): 
        return self.ip_cols;    
    
    def get_feature_names_out(self, X, y=None, **params): 
        return self.op_cols;
    
collect();
print();
# Out:
# CPU times: user 196 ms, sys: 0 ns, total: 196 ms
# Wall time: 195 ms

# %%
# %%time

# Scaling
class Scaler(TransformerMixin,BaseEstimator):
    """
    This class aims to scale the provided dataset
    """
    
    def __init__(self,scl_method:str,scl_req:str,scl_cols):
        self.scl_method=scl_method;
        self.scl_req=scl_req;
        self.scl_cols=scl_cols;
    
    def fit(self,X,y=None,**params):
        """
        This function calculates the train-set paramaters for scaling
        """
        self.params=X[self.scl_cols].describe(percentiles=[0.25,0.5,0.75]).drop(['count'],axis=0).T;
        self.params['iqr']=self.params['75%']-self.params['25%'];
        self.params['range']=self.params['max']-self.params['min'];
        return self;
    
    def transform(self,X,y=None,**params):
        """
        This function transform the relevant scaling columns
        """
        df=X.copy();
        if self.scl_req=="Y":
            if CFG.scl_method=="Z":
                df[self.scl_cols]=(df[self.scl_cols].values-self.params['mean'].values)/self.params['std'].values;
            elif CFG.scl_method == "Robust":
                df[self.scl_cols] = (df[self.scl_cols].values - self.params['50%'].values) / self.params['iqr'].values;
            elif CFG.scl_method == "MinMax":
                df[self.scl_cols] = (df[self.scl_cols].values - self.params['min'].values) / self.params['range'].values;
        else:
            PrintColor(f"Scaling is not needed",color=Fore.RED)
        return df;
# Out:
# CPU times: user 266 µs, sys: 42 µs, total: 308 µs
# Wall time: 314 µs

# %%
# %%time

PrintColor(f"\n{'='*20} Data transformation {'='*20} \n");

ytrain=train[CFG.target].astype(np.float32);
mapper = {209: 200, 220: 229, 230: 229, 260: 250, 410: 400, 469: 480, 
          540: 550, 575: 580, 640: 650, 664: 650, 670: 680, 810: 800, 830: 850, 
          980: 1000
         };

if CFG.tgt_scl_fct>1:
    ytrain=(ytrain*CFG.tgt_scl_fct).astype(np.uint16);
    # cleaning the targets
    for k,v in mapper.items():
        ytrain.loc[ytrain==k]==v;
        
Xtrain=train.drop(columns=[CFG.target]);
Xtest=test.copy(deep=True);

PrintColor(f"\n--> Train data\n")
display(Xtrain.head(5).style.format(precision=2));
PrintColor(f"\n--> Test data\n")
display(Xtest.head(5).style.format(precision=2));

print();

xform=Pipeline(steps=[("Xform",Xformer())]);
Xtrain=xform.fit_transform(Xtrain,ytrain);
Xtest=xform.transform(Xtest);
print();

PrintColor(f"\n---> Train data columns after data pipeline\n");
pprint(Xtrain.columns)

PrintColor(f"\n---> Test data columns after data pipeline\n");
pprint(Xtest.columns)
PrintColor(f"\n---> Train-test shape after pipeline = {Xtrain.shape} {Xtest.shape}\n");

PrintColor(f"---> Dropping duplicates in the training Data");
_=pd.concat([Xtrain,ytrain],axis=1).drop_duplicates(subset=Xtrain.columns[0:-1].to_list());
_.index=range(len(_));
Xtrain,ytrain=_.drop(columns=[CFG.target]),_[CFG.target];
del _;
PrintColor(f"---> Train-test shape after duplicate removal = {Xtrain.shape} {Xtest.shape}");

print();
collect();
# Out:
# ==================== Data transformation ====================
#
#
# --> Train data
# <style type="text/css">
# </style>
# <table id="T_15c1b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15c1b_level0_col0" class="col_heading level0 col0" >allelectrons_Total</th>
#       <th id="T_15c1b_level0_col1" class="col_heading level0 col1" >density_Total</th>
#       <th id="T_15c1b_level0_col2" class="col_heading level0 col2" >allelectrons_Average</th>
#       <th id="T_15c1b_level0_col3" class="col_heading level0 col3" >val_e_Average</th>
#       <th id="T_15c1b_level0_col4" class="col_heading level0 col4" >atomicweight_Average</th>
#       <th id="T_15c1b_level0_col5" class="col_heading level0 col5" >ionenergy_Average</th>
#       <th id="T_15c1b_level0_col6" class="col_heading level0 col6" >el_neg_chi_Average</th>
#       <th id="T_15c1b_level0_col7" class="col_heading level0 col7" >R_vdw_element_Average</th>
#       <th id="T_15c1b_level0_col8" class="col_heading level0 col8" >R_cov_element_Average</th>
#       <th id="T_15c1b_level0_col9" class="col_heading level0 col9" >zaratio_Average</th>
#       <th id="T_15c1b_level0_col10" class="col_heading level0 col10" >density_Average</th>
#       <th id="T_15c1b_level0_col11" class="col_heading level0 col11" >Source</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15c1b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_15c1b_row0_col0" class="data row0 col0" >100</td>
#       <td id="T_15c1b_row0_col1" class="data row0 col1" >0.84</td>
#       <td id="T_15c1b_row0_col2" class="data row0 col2" >10.00</td>
#       <td id="T_15c1b_row0_col3" class="data row0 col3" >4.80</td>
#       <td id="T_15c1b_row0_col4" class="data row0 col4" >20.61</td>
#       <td id="T_15c1b_row0_col5" class="data row0 col5" >11.09</td>
#       <td id="T_15c1b_row0_col6" class="data row0 col6" >2.77</td>
#       <td id="T_15c1b_row0_col7" class="data row0 col7" >1.73</td>
#       <td id="T_15c1b_row0_col8" class="data row0 col8" >0.86</td>
#       <td id="T_15c1b_row0_col9" class="data row0 col9" >0.50</td>
#       <td id="T_15c1b_row0_col10" class="data row0 col10" >0.91</td>
#       <td id="T_15c1b_row0_col11" class="data row0 col11" >Competition</td>
#     </tr>
#     <tr>
#       <th id="T_15c1b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_15c1b_row1_col0" class="data row1 col0" >100</td>
#       <td id="T_15c1b_row1_col1" class="data row1 col1" >7.56</td>
#       <td id="T_15c1b_row1_col2" class="data row1 col2" >10.00</td>
#       <td id="T_15c1b_row1_col3" class="data row1 col3" >4.80</td>
#       <td id="T_15c1b_row1_col4" class="data row1 col4" >20.30</td>
#       <td id="T_15c1b_row1_col5" class="data row1 col5" >12.04</td>
#       <td id="T_15c1b_row1_col6" class="data row1 col6" >2.75</td>
#       <td id="T_15c1b_row1_col7" class="data row1 col7" >1.63</td>
#       <td id="T_15c1b_row1_col8" class="data row1 col8" >0.91</td>
#       <td id="T_15c1b_row1_col9" class="data row1 col9" >0.49</td>
#       <td id="T_15c1b_row1_col10" class="data row1 col10" >0.72</td>
#       <td id="T_15c1b_row1_col11" class="data row1 col11" >Competition</td>
#     </tr>
#     <tr>
#       <th id="T_15c1b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_15c1b_row2_col0" class="data row2 col0" >76</td>
#       <td id="T_15c1b_row2_col1" class="data row2 col1" >8.89</td>
#       <td id="T_15c1b_row2_col2" class="data row2 col2" >15.60</td>
#       <td id="T_15c1b_row2_col3" class="data row2 col3" >5.60</td>
#       <td id="T_15c1b_row2_col4" class="data row2 col4" >33.74</td>
#       <td id="T_15c1b_row2_col5" class="data row2 col5" >12.09</td>
#       <td id="T_15c1b_row2_col6" class="data row2 col6" >2.83</td>
#       <td id="T_15c1b_row2_col7" class="data row2 col7" >1.79</td>
#       <td id="T_15c1b_row2_col8" class="data row2 col8" >0.86</td>
#       <td id="T_15c1b_row2_col9" class="data row2 col9" >0.48</td>
#       <td id="T_15c1b_row2_col10" class="data row2 col10" >1.51</td>
#       <td id="T_15c1b_row2_col11" class="data row2 col11" >Competition</td>
#     </tr>
#     <tr>
#       <th id="T_15c1b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_15c1b_row3_col0" class="data row3 col0" >100</td>
#       <td id="T_15c1b_row3_col1" class="data row3 col1" >8.80</td>
#       <td id="T_15c1b_row3_col2" class="data row3 col2" >10.00</td>
#       <td id="T_15c1b_row3_col3" class="data row3 col3" >4.80</td>
#       <td id="T_15c1b_row3_col4" class="data row3 col4" >20.21</td>
#       <td id="T_15c1b_row3_col5" class="data row3 col5" >10.95</td>
#       <td id="T_15c1b_row3_col6" class="data row3 col6" >2.65</td>
#       <td id="T_15c1b_row3_col7" class="data row3 col7" >1.63</td>
#       <td id="T_15c1b_row3_col8" class="data row3 col8" >0.94</td>
#       <td id="T_15c1b_row3_col9" class="data row3 col9" >0.49</td>
#       <td id="T_15c1b_row3_col10" class="data row3 col10" >0.79</td>
#       <td id="T_15c1b_row3_col11" class="data row3 col11" >Competition</td>
#     </tr>
#     <tr>
#       <th id="T_15c1b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_15c1b_row4_col0" class="data row4 col0" >116</td>
#       <td id="T_15c1b_row4_col1" class="data row4 col1" >9.58</td>
#       <td id="T_15c1b_row4_col2" class="data row4 col2" >11.60</td>
#       <td id="T_15c1b_row4_col3" class="data row4 col3" >4.80</td>
#       <td id="T_15c1b_row4_col4" class="data row4 col4" >24.99</td>
#       <td id="T_15c1b_row4_col5" class="data row4 col5" >11.82</td>
#       <td id="T_15c1b_row4_col6" class="data row4 col6" >2.77</td>
#       <td id="T_15c1b_row4_col7" class="data row4 col7" >1.68</td>
#       <td id="T_15c1b_row4_col8" class="data row4 col8" >0.90</td>
#       <td id="T_15c1b_row4_col9" class="data row4 col9" >0.49</td>
#       <td id="T_15c1b_row4_col10" class="data row4 col10" >1.86</td>
#       <td id="T_15c1b_row4_col11" class="data row4 col11" >Competition</td>
#     </tr>
#   </tbody>
# </table>
# --> Test data
# <style type="text/css">
# </style>
# <table id="T_66cab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66cab_level0_col0" class="col_heading level0 col0" >allelectrons_Total</th>
#       <th id="T_66cab_level0_col1" class="col_heading level0 col1" >density_Total</th>
#       <th id="T_66cab_level0_col2" class="col_heading level0 col2" >allelectrons_Average</th>
#       <th id="T_66cab_level0_col3" class="col_heading level0 col3" >val_e_Average</th>
#       <th id="T_66cab_level0_col4" class="col_heading level0 col4" >atomicweight_Average</th>
#       <th id="T_66cab_level0_col5" class="col_heading level0 col5" >ionenergy_Average</th>
#       <th id="T_66cab_level0_col6" class="col_heading level0 col6" >el_neg_chi_Average</th>
#       <th id="T_66cab_level0_col7" class="col_heading level0 col7" >R_vdw_element_Average</th>
#       <th id="T_66cab_level0_col8" class="col_heading level0 col8" >R_cov_element_Average</th>
#       <th id="T_66cab_level0_col9" class="col_heading level0 col9" >zaratio_Average</th>
#       <th id="T_66cab_level0_col10" class="col_heading level0 col10" >density_Average</th>
#       <th id="T_66cab_level0_col11" class="col_heading level0 col11" >Source</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66cab_level0_row0" class="row_heading level0 row0" >10407</th>
#       <td id="T_66cab_row0_col0" class="data row0 col0" >884</td>
#       <td id="T_66cab_row0_col1" class="data row0 col1" >121.42</td>
#       <td id="T_66cab_row0_col2" class="data row0 col2" >35.36</td>
#       <td id="T_66cab_row0_col3" class="data row0 col3" >5.28</td>
#       <td id="T_66cab_row0_col4" class="data row0 col4" >82.56</td>
#       <td id="T_66cab_row0_col5" class="data row0 col5" >9.37</td>
#       <td id="T_66cab_row0_col6" class="data row0 col6" >2.30</td>
#       <td id="T_66cab_row0_col7" class="data row0 col7" >1.91</td>
#       <td id="T_66cab_row0_col8" class="data row0 col8" >1.20</td>
#       <td id="T_66cab_row0_col9" class="data row0 col9" >0.46</td>
#       <td id="T_66cab_row0_col10" class="data row0 col10" >1.79</td>
#       <td id="T_66cab_row0_col11" class="data row0 col11" >Competition</td>
#     </tr>
#     <tr>
#       <th id="T_66cab_level0_row1" class="row_heading level0 row1" >10408</th>
#       <td id="T_66cab_row1_col0" class="data row1 col0" >90</td>
#       <td id="T_66cab_row1_col1" class="data row1 col1" >9.93</td>
#       <td id="T_66cab_row1_col2" class="data row1 col2" >18.00</td>
#       <td id="T_66cab_row1_col3" class="data row1 col3" >5.60</td>
#       <td id="T_66cab_row1_col4" class="data row1 col4" >39.57</td>
#       <td id="T_66cab_row1_col5" class="data row1 col5" >12.09</td>
#       <td id="T_66cab_row1_col6" class="data row1 col6" >2.87</td>
#       <td id="T_66cab_row1_col7" class="data row1 col7" >1.65</td>
#       <td id="T_66cab_row1_col8" class="data row1 col8" >0.86</td>
#       <td id="T_66cab_row1_col9" class="data row1 col9" >0.48</td>
#       <td id="T_66cab_row1_col10" class="data row1 col10" >1.41</td>
#       <td id="T_66cab_row1_col11" class="data row1 col11" >Competition</td>
#     </tr>
#     <tr>
#       <th id="T_66cab_level0_row2" class="row_heading level0 row2" >10409</th>
#       <td id="T_66cab_row2_col0" class="data row2 col0" >116</td>
#       <td id="T_66cab_row2_col1" class="data row2 col1" >7.77</td>
#       <td id="T_66cab_row2_col2" class="data row2 col2" >11.60</td>
#       <td id="T_66cab_row2_col3" class="data row2 col3" >4.80</td>
#       <td id="T_66cab_row2_col4" class="data row2 col4" >23.23</td>
#       <td id="T_66cab_row2_col5" class="data row2 col5" >11.02</td>
#       <td id="T_66cab_row2_col6" class="data row2 col6" >2.64</td>
#       <td id="T_66cab_row2_col7" class="data row2 col7" >1.79</td>
#       <td id="T_66cab_row2_col8" class="data row2 col8" >0.96</td>
#       <td id="T_66cab_row2_col9" class="data row2 col9" >0.50</td>
#       <td id="T_66cab_row2_col10" class="data row2 col10" >0.79</td>
#       <td id="T_66cab_row2_col11" class="data row2 col11" >Competition</td>
#     </tr>
#     <tr>
#       <th id="T_66cab_level0_row3" class="row_heading level0 row3" >10410</th>
#       <td id="T_66cab_row3_col0" class="data row3 col0" >100</td>
#       <td id="T_66cab_row3_col1" class="data row3 col1" >9.11</td>
#       <td id="T_66cab_row3_col2" class="data row3 col2" >10.00</td>
#       <td id="T_66cab_row3_col3" class="data row3 col3" >4.80</td>
#       <td id="T_66cab_row3_col4" class="data row3 col4" >20.30</td>
#       <td id="T_66cab_row3_col5" class="data row3 col5" >12.09</td>
#       <td id="T_66cab_row3_col6" class="data row3 col6" >2.83</td>
#       <td id="T_66cab_row3_col7" class="data row3 col7" >1.66</td>
#       <td id="T_66cab_row3_col8" class="data row3 col8" >0.79</td>
#       <td id="T_66cab_row3_col9" class="data row3 col9" >0.50</td>
#       <td id="T_66cab_row3_col10" class="data row3 col10" >1.20</td>
#       <td id="T_66cab_row3_col11" class="data row3 col11" >Competition</td>
#     </tr>
#     <tr>
#       <th id="T_66cab_level0_row4" class="row_heading level0 row4" >10411</th>
#       <td id="T_66cab_row4_col0" class="data row4 col0" >55</td>
#       <td id="T_66cab_row4_col1" class="data row4 col1" >4.03</td>
#       <td id="T_66cab_row4_col2" class="data row4 col2" >11.00</td>
#       <td id="T_66cab_row4_col3" class="data row4 col3" >4.00</td>
#       <td id="T_66cab_row4_col4" class="data row4 col4" >22.98</td>
#       <td id="T_66cab_row4_col5" class="data row4 col5" >11.28</td>
#       <td id="T_66cab_row4_col6" class="data row4 col6" >2.46</td>
#       <td id="T_66cab_row4_col7" class="data row4 col7" >1.75</td>
#       <td id="T_66cab_row4_col8" class="data row4 col8" >0.89</td>
#       <td id="T_66cab_row4_col9" class="data row4 col9" >0.48</td>
#       <td id="T_66cab_row4_col10" class="data row4 col10" >0.93</td>
#       <td id="T_66cab_row4_col11" class="data row4 col11" >Competition</td>
#     </tr>
#   </tbody>
# </table>
# Start - end memory:-  0.94 -  0.52 Mb
# Start - end memory:-  0.65 -  0.38 Mb
#
#
# ---> Train data columns after data pipeline
#
# Index(['allelectrons_Total', 'density_Total', 'allelectrons_Average',
#        'val_e_Average', 'atomicweight_Average', 'ionenergy_Average',
#        'el_neg_chi_Average', 'R_vdw_element_Average', 'R_cov_element_Average',
#        'zaratio_Average', 'density_Average', 'Source'],
#       dtype='object')
#
# ---> Test data columns after data pipeline
#
# Index(['allelectrons_Total', 'density_Total', 'allelectrons_Average',
#        'val_e_Average', 'atomicweight_Average', 'ionenergy_Average',
#        'el_neg_chi_Average', 'R_vdw_element_Average', 'R_cov_element_Average',
#        'zaratio_Average', 'density_Average', 'Source'],
#       dtype='object')
#
# ---> Train-test shape after pipeline = (11006, 12) (6939, 12)
#
# ---> Dropping duplicates in the training Data
# ---> Train-test shape after duplicate removal = (10939, 12) (6939, 12)
#
# CPU times: user 262 ms, sys: 3.6 ms, total: 266 ms
# Wall time: 261 ms

# %%
# %%time 

# Shortlisting the duplicate data between train and test dataframes for post-processing:-
join_cols = Xtrain.columns[0:-1].to_list();

dups_df = \
Xtrain.\
reset_index(names = "id").\
assign(Label = "Train").\
merge(Xtest.reset_index().assign(Label = "Test"),
      how = "inner", on = join_cols, suffixes = ("_train", "_test")).\
drop(columns = join_cols).\
merge(ytrain, how = "inner", left_on = "id_train", right_index = True)\
[['id_train', 'id_test', CFG.target]].\
drop_duplicates(subset = ['id_test']);

del join_cols;

PrintColor(f"\n---> Train-test duplicate data glimpse- shape = {dups_df.shape}");
display(dups_df.head(10).style.format(precision = 3));
dups_df.to_csv(f"Duplicates.csv", index = None);

collect();
print();
# Out:
# ---> Train-test duplicate data glimpse- shape = (39, 3)
# <style type="text/css">
# </style>
# <table id="T_e9824">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9824_level0_col0" class="col_heading level0 col0" >id_train</th>
#       <th id="T_e9824_level0_col1" class="col_heading level0 col1" >id_test</th>
#       <th id="T_e9824_level0_col2" class="col_heading level0 col2" >Hardness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9824_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e9824_row0_col0" class="data row0 col0" >580</td>
#       <td id="T_e9824_row0_col1" class="data row0 col1" >10824</td>
#       <td id="T_e9824_row0_col2" class="data row0 col2" >650</td>
#     </tr>
#     <tr>
#       <th id="T_e9824_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e9824_row1_col0" class="data row1 col0" >580</td>
#       <td id="T_e9824_row1_col1" class="data row1 col1" >13823</td>
#       <td id="T_e9824_row1_col2" class="data row1 col2" >650</td>
#     </tr>
#     <tr>
#       <th id="T_e9824_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e9824_row2_col0" class="data row2 col0" >1871</td>
#       <td id="T_e9824_row2_col1" class="data row2 col1" >16403</td>
#       <td id="T_e9824_row2_col2" class="data row2 col2" >380</td>
#     </tr>
#     <tr>
#       <th id="T_e9824_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e9824_row3_col0" class="data row3 col0" >3097</td>
#       <td id="T_e9824_row3_col1" class="data row3 col1" >12024</td>
#       <td id="T_e9824_row3_col2" class="data row3 col2" >500</td>
#     </tr>
#     <tr>
#       <th id="T_e9824_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e9824_row4_col0" class="data row4 col0" >3483</td>
#       <td id="T_e9824_row4_col1" class="data row4 col1" >13131</td>
#       <td id="T_e9824_row4_col2" class="data row4 col2" >600</td>
#     </tr>
#     <tr>
#       <th id="T_e9824_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e9824_row5_col0" class="data row5 col0" >5956</td>
#       <td id="T_e9824_row5_col1" class="data row5 col1" >12618</td>
#       <td id="T_e9824_row5_col2" class="data row5 col2" >550</td>
#     </tr>
#     <tr>
#       <th id="T_e9824_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e9824_row6_col0" class="data row6 col0" >6487</td>
#       <td id="T_e9824_row6_col1" class="data row6 col1" >14760</td>
#       <td id="T_e9824_row6_col2" class="data row6 col2" >380</td>
#     </tr>
#     <tr>
#       <th id="T_e9824_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e9824_row7_col0" class="data row7 col0" >7649</td>
#       <td id="T_e9824_row7_col1" class="data row7 col1" >12559</td>
#       <td id="T_e9824_row7_col2" class="data row7 col2" >680</td>
#     </tr>
#     <tr>
#       <th id="T_e9824_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e9824_row8_col0" class="data row8 col0" >7917</td>
#       <td id="T_e9824_row8_col1" class="data row8 col1" >16644</td>
#       <td id="T_e9824_row8_col2" class="data row8 col2" >580</td>
#     </tr>
#     <tr>
#       <th id="T_e9824_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e9824_row9_col0" class="data row9 col0" >8111</td>
#       <td id="T_e9824_row9_col1" class="data row9 col1" >10777</td>
#       <td id="T_e9824_row9_col2" class="data row9 col2" >150</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 234 ms, sys: 3.54 ms, total: 237 ms
# Wall time: 243 ms

# %%
# %%time 

# Reducing to small sample for training as part of syntax testing:-
if CFG.test_req == "Y":
    PrintColor(f"\n---> Testing syntax and reducing data size");
    
    if isinstance(CFG.test_sample_frac, float) == True:
        Xtrain = \
        pd.concat([Xtrain, ytrain], axis=1).\
        groupby([CFG.target]).\
        sample(frac = CFG.test_sample_frac);
        
       
    elif isinstance(CFG.test_sample_frac, int) == True:
        Xtrain = \
        pd.concat([Xtrain, ytrain], axis=1).\
        groupby([CFG.target]).\
        sample(n = CFG.test_sample_frac);
        
    ytrain = ytrain.loc[ytrain.index.isin(Xtrain.index)];
    Xtrain.index = range(len(Xtrain));
    ytrain.index = range(len(ytrain)); 
    
else:
    PrintColor(f"\n---> We are not testing syntax here\n");
    
PrintColor(f"---> Train-test shape after syntax check = {Xtrain.shape} {ytrain.shape} {Xtest.shape}");
    
print();
collect();
# Out:
# ---> We are not testing syntax here
#
# ---> Train-test shape after syntax check = (10939, 12) (10939,) (6939, 12)
#
# CPU times: user 200 ms, sys: 0 ns, total: 200 ms
# Wall time: 199 ms

# %% [markdown]
# # Model Training

# %%
# %%time 

# Initializing model I-O:-

Mdl_Master = \
{'CB1R': CatBoostRegressor(**{ 'task_type'          : "GPU" if CFG.gpu_switch == "ON" else "CPU",
                              'objective'           : 'Quantile:alpha=0.50',
                              'loss_function'       : 'Quantile:alpha=0.50',
                              'eval_metric'         : 'Quantile:alpha=0.50',
                              'bagging_temperature' : 0.1,
                              'colsample_bylevel'   : 0.88,
                              'iterations'          : 1000,
                              'learning_rate'       : 0.035,
                              'od_wait'             : 12,
                              'max_depth'           : 7,
                              'l2_leaf_reg'         : 1.75,
                              'min_data_in_leaf'    : 20,
                              'random_strength'     : 0.1, 
                              'max_bin'             : 100,
                              'verbose'             : 0,
                              'use_best_model'      : True,
                           }
                         ),
 
 'CB2R': CatBoostRegressor(**{'task_type'           : "GPU" if CFG.gpu_switch == "ON" else "CPU",
                              'objective'           : 'Quantile:alpha=0.50',
                              'loss_function'       : 'Quantile:alpha=0.50',
                              'eval_metric'         : 'Quantile:alpha=0.50',
                              'bagging_temperature' : 0.75,
                              'colsample_bylevel'   : 0.35,
                              'iterations'          : 1000,
                              'learning_rate'       : 0.025,
                              'od_wait'             : 23,
                              'max_depth'           : 6,
                              'l2_leaf_reg'         : 2.5,
                              'min_data_in_leaf'    : 16,
                              'random_strength'     : 0.1, 
                              'max_bin'             : 140,
                              'verbose'             : 0,
                              'use_best_model'      : True,
                           }
                         ),
 
  'CB3R': CatBoostRegressor(**{'task_type'           : "GPU" if CFG.gpu_switch == "ON" else "CPU",
                              'objective'           : 'Quantile:alpha=0.50',
                              'loss_function'       : 'Quantile:alpha=0.50',
                              'eval_metric'         : 'Quantile:alpha=0.50',
                              'bagging_temperature' : 0.35,
                              'colsample_bylevel'   : 0.5,
                              'iterations'          : 1000,
                              'learning_rate'       : 0.04,
                              'od_wait'             : 30,
                              'max_depth'           : 5,
                              'l2_leaf_reg'         : 1.35,
                              'min_data_in_leaf'    : 24,
                              'random_strength'     : 0.5, 
                              'max_bin'             : 80,
                              'verbose'             : 0,
                              'use_best_model'      : True,
                           }
                         ), 

  'XGB1R': XGBRegressor(**{'tree_method'        : "gpu_hist" if CFG.gpu_switch == "ON" else "hist",
                           'objective'          : 'reg:quantileerror',
                           'quantile_alpha'     : 0.50,
                           'random_state'       : CFG.state,
                           'colsample_bytree'   : 0.7,
                           'learning_rate'      : 0.02,
                           'max_depth'          : 9,
                           'n_estimators'       : 1100,                         
                           'reg_alpha'          : 0.0035,
                           'reg_lambda'         : 0.0012,
                           'min_child_weight'   : 16,
                           'early_stopping_rounds' : CFG.nbrnd_erly_stp,
                        }
                       ),
 
  'XGB2R': XGBRegressor(**{'tree_method'         : "gpu_hist" if CFG.gpu_switch == "ON" else "hist",
                            'objective'          : 'reg:quantileerror',
                            'quantile_alpha'     : 0.50,
                            'random_state'       : CFG.state,
                            'colsample_bytree'   : 0.25,
                            'learning_rate'      : 0.08,
                            'max_depth'          : 8,
                            'n_estimators'       : 1100,                         
                            'reg_alpha'          : 0.1,
                            'reg_lambda'         : 0.0001,
                            'min_child_weight'   : 25,
                            'early_stopping_rounds' : CFG.nbrnd_erly_stp,
                           }
                        ),
 
   'XGB3R': XGBRegressor(**{'tree_method'        : "gpu_hist" if CFG.gpu_switch == "ON" else "hist",
                            'objective'          : 'reg:quantileerror',
                            'quantile_alpha'     : 0.50,
                            'random_state'       : CFG.state,
                            'colsample_bytree'   : 0.50,
                            'learning_rate'      : 0.025,
                            'max_depth'          : 6,
                            'n_estimators'       : 1100,                         
                            'reg_alpha'          : 0.01,
                            'reg_lambda'         : 0.01,
                            'min_child_weight'   : 21,
                            'early_stopping_rounds' : CFG.nbrnd_erly_stp,
                           }
                        ), 

   "HGBR":  HGBR(loss              = 'quantile',
                 quantile          = 0.50,
                 learning_rate     = 0.07,
                 early_stopping    = True,
                 max_iter          = 200,
                 max_depth         = 5,
                 min_samples_leaf  = 23,
                 l2_regularization = 1.75,
                 scoring           = myscorer,
                 random_state      = CFG.state,
                ),
};

print();
collect();
# Out:
# CPU times: user 194 ms, sys: 8.24 ms, total: 203 ms
# Wall time: 203 ms

# %%
# %%time

if CFG.ML == "Y":

    # Initializing output tables for the models:-
    if CFG.test_req == "Y" or CFG.pseudo_lbl_req == "Y":
        methods = ["CB1R", "CB2R", "XGB1R", 'XGB2R'];
    else:
        methods = list(Mdl_Master.keys());
  
    sel_cols  = Xtrain.columns.to_list();
    cat_ftre  = cat_cols;
    scl_ftre  = cont_cols;
    
    if CFG.mdlcv_mthd in ("SKF", "RSKF"):
        y_grp = np.uint8(ytrain / CFG.tgt_scl_fct);
    else:
        y_grp = ytrain.values;
    
    OOF_Preds = pd.DataFrame(columns = methods);
    Mdl_Preds = pd.DataFrame(index = pp.sub_fl['id'], columns = methods);
    FtreImp   = pd.DataFrame(index = sel_cols[0:-1], columns = methods);
    Scores    = pd.DataFrame(columns = methods);

    PrintColor(f"\n---> Selected model options- ");
    pprint(methods, depth = 1, width = 100, indent = 5);
    
    PrintColor(f"\n---> Selected category columns- ");
    pprint(np.array(cat_ftre), depth = 1, width = 100, indent = 5);
    
    PrintColor(f"\n---> Selected transformation columns- ");
    pprint(np.array(scl_ftre), depth = 1, width = 100, indent = 5);

print();
collect();
# Out:
# ---> Selected model options-
# ['CB1R', 'CB2R', 'CB3R', 'XGB1R', 'XGB2R', 'XGB3R', 'HGBR']
#
# ---> Selected category columns-
# array([], dtype=float64)
#
# ---> Selected transformation columns-
# array(['allelectrons_Total', 'density_Total', 'allelectrons_Average',
#        'val_e_Average', 'atomicweight_Average', 'ionenergy_Average',
#        'el_neg_chi_Average', 'R_vdw_element_Average',
#        'R_cov_element_Average', 'zaratio_Average', 'density_Average'],
#       dtype='<U21')
#
# CPU times: user 210 ms, sys: 4.09 ms, total: 214 ms
# Wall time: 210 ms

# %%
# %%time 

def TrainMdl(method:str):
    
    global Mdl_Master, Mdl_Preds, OOF_Preds, \
    all_cv, FtreImp, Xtrain, ytrain, y_grp, \
    sel_cols, risk_ftre, scl_ftre ; 
    
    if method.startswith("KNN") or method.startswith("RIDGE") or \
    method.startswith("LT") == True or method.startswith("SV") == True:
        c_xform = \
        ColumnTransformer([("CXform", all_scalers[CFG.scl_method], scl_ftre)
                          ], remainder = 'passthrough', verbose_feature_names_out = False
                         ); 
        model = Pipeline(steps = [("T", c_xform), ("M", Mdl_Master.get(method))]); 
         
    else: 
        model = Pipeline(steps = [("M", Mdl_Master.get(method))]); 
    
    cv        = all_cv.get(CFG.mdlcv_mthd);
    Xt        = Xtest[sel_cols];
    
    if CFG.use_orig_allfolds == "Y":
        X    = Xtrain[sel_cols].query("Source == 'Competition'");
        y    = ytrain.loc[ytrain.index.isin(X.index)]; 
        Orig = pd.concat([Xtrain, ytrain], axis=1).query("Source == 'Original'")[sel_cols];
        
    elif CFG.use_orig_allfolds != "Y":
        X,y = Xtrain[sel_cols], ytrain.copy(deep = True);
                  
    # Initializing I-O for the given seed:-        
    test_preds = 0;
    oof_preds  = pd.DataFrame(); 
    scores     = [];
    ftreimp    = 0;
    cols_drop  = ['Source', "id"];
       
    for fold_nb, (train_idx, dev_idx) in enumerate(cv.split(X, y_grp)):
        Xtr  = X.iloc[train_idx].drop(columns = cols_drop, errors = 'ignore');  
        Xdev = X.iloc[dev_idx].loc[X.Source == "Competition"].\
        drop(columns = cols_drop, errors = 'ignore'); 
        ytr  = y.loc[y.index.isin(Xtr.index)];
        ydev = y.loc[y.index.isin(Xdev.index)];
        
        if CFG.test_req == "Y":
            print(f"---> {Xtr.shape} {Xdev.shape} {ytr.shape} {ydev.shape} {Xt.shape}");
        else:
            pass;

        if CFG.use_orig_allfolds == "Y":
            Xtr = pd.concat([Xtr, Orig.drop(columns = [CFG.target, 'Source'], errors = 'ignore')], 
                            axis = 0, ignore_index = True);
            ytr = pd.concat([ytr, Orig[CFG.target]], axis = 0, ignore_index = True);
            
        # Fitting the model:-          
        if "CB" in method:    
            model.fit(Xtr, ytr, 
                      M__eval_set = [(Xdev, ydev)], 
                      M__verbose = 0,
                      M__early_stopping_rounds = CFG.nbrnd_erly_stp,
                     ); 
        
        elif "LGBM" in method:
            model.fit(Xtr, ytr, 
                      M__eval_set = [(Xdev, ydev)], 
                      M__callbacks = [log_evaluation(0), 
                                      early_stopping(stopping_rounds = CFG.nbrnd_erly_stp, 
                                                     verbose = False,),
                                     ],
                     ); 
            
        elif "XGB" in method:
             model.fit(Xtr, ytr, 
                       M__eval_set = [(Xdev, ydev)], 
                       M__verbose = 0,
                      );            
            
        else: 
            model.fit(Xtr, ytr,); 
                 
        # Collecting predictions and scores and post-processing OOF based on model method:-
        dev_preds   = PostProcessPred(model.predict(Xdev), post_process= CFG.pstprcs_train);
        test_preds  = test_preds + \
        PostProcessPred(model.predict(Xt.drop(columns = cols_drop, errors = 'ignore')),
                        post_process= CFG.pstprcs_train);
        train_preds = PostProcessPred(model.predict(Xtr), post_process= CFG.pstprcs_train);
          
        tr_score = ScoreMetric(ytr.values.flatten(), train_preds);
        score = ScoreMetric(ydev.values.flatten(), dev_preds);
        scores.append(score); 
        
        Scores.loc[fold_nb, method] = np.round(score, decimals= 6);
        oof_preds = pd.concat([oof_preds,
                               pd.DataFrame(index   = Xdev.index, 
                                            data    = dev_preds,
                                            columns = [method])
                              ],axis=0, ignore_index= False
                             ); 
        
        num_space = 3 if fold_nb <= 9 else 2;
        PrintColor(f"Fold{fold_nb} {' ' * num_space} OOF = {score:.5f} | Train = {tr_score:.5f}| {method}", 
                   color = Fore.GREEN);
        del num_space;
    
        oof_preds = pd.DataFrame(oof_preds.groupby(level = 0)[method].mean());
        oof_preds.columns = [method];
        
        try: 
            ftreimp += model["M"].feature_importances_;
        except: 
            ftreimp = 0;
            
    num_space = 10 - len(method);
    PrintColor(f"--> {method}{'-' * num_space} CV = {np.mean(scores):.6f}\n");
    del num_space;
    
    OOF_Preds[f'{method}'] = PostProcessPred(oof_preds.values.flatten(), CFG.pstprcs_train);
    
    if CFG.mdlcv_mthd in ['KF', 'SKF']:
        Mdl_Preds[f'{method}'] = test_preds.flatten()/ CFG.n_splits; 
        FtreImp[method]        = ftreimp / CFG.n_splits;
    else:
        Mdl_Preds[f'{method}'] = test_preds.flatten()/ (CFG.n_splits * CFG.n_repeats); 
        FtreImp[method]        = ftreimp / (CFG.n_splits * CFG.n_repeats);
    
    collect(); 
    
print();
collect();
# Out:
# CPU times: user 198 ms, sys: 3.46 ms, total: 202 ms
# Wall time: 199 ms

# %%
# %%time 

def MakePseudoLbl(Mdl_Preds: pd.DataFrame, ytrain: pd.Series, 
                  Xtrain: pd.DataFrame, Xtest: pd.DataFrame, 
                  up_cutoff: float, low_cutoff: float,
                  **kwargs
                 ):
    "This function combines the confident test-set predictions to the train set for 2nd stage pseudo labels";
    
    test_preds = np.mean(Mdl_Preds, axis=1).to_frame();
    test_preds.rename(columns = {0: CFG.target}, inplace = True);
    test_preds[CFG.target] = np.select([test_preds[CFG.target].values >= 0.90, 
                                        test_preds[CFG.target].values <= 0.05
                                       ], [1, 0], -1
                                      );
    test_preds = test_preds.loc[test_preds[CFG.target] >= 0];
    
    display(test_preds.head(10));
    
    PrintColor(f"Rows to be added to the training data = {test_preds.shape[0]}");
    
    test_preds = pd.concat([Xtest, test_preds], axis=1, join= "inner");
    
    Xtrain = pd.concat([Xtrain, test_preds[Xtrain.columns]], axis=0, ignore_index = True);
    Xtrain.index = range(len(Xtrain));
    ytrain = pd.concat([ytrain, test_preds[CFG.target].astype(np.uint8)], 
                       axis=0, ignore_index = True
                      );
    ytrain.index = range(len(ytrain));
    
    PrintColor(f"Training data shape for 2nd stage pseudo labels = {Xtrain.shape} {ytrain.shape}");
    
    return Xtrain, ytrain;
# Out:
# CPU times: user 13 µs, sys: 0 ns, total: 13 µs
# Wall time: 17.4 µs

# %%
# %%time

if CFG.pseudo_lbl_req == "Y" and CFG.ML == "Y":
    # Implementing the ML models for 1st stage pseudo labels:-
    PrintColor(f"\n{'-' * 25} ML model training- Stage1 Pseudo Labels {'-' * 25}\n", 
               color = Fore.MAGENTA
              );
    for method in tqdm(methods, "ML models----"): 
        TrainMdl(method);
   
    PrintColor(f"\n{'-' * 20} OOF CV scores across methods- Stage1 Pseudo Labels {'-' * 20}\n", 
                   color = Fore.MAGENTA);
    display(pd.concat([Scores.mean(axis = 0), Scores.std(axis = 0)], axis=1).\
            rename(columns = {0: 'Mean', 1: 'Std'}).T.\
            style.format(precision = 6).\
            background_gradient(subset = methods, cmap = 'cubehelix', axis=1)
           );  
    
    # Combining confident test-set predictions to the train-set:- 
    Xtrain, ytrain = MakePseudoLbl(**{'Mdl_Preds': Mdl_Preds, 
                                      'ytrain'   : ytrain, 
                                      'Xtrain'   : Xtrain, 
                                      'Xtest'    : Xtest, 
                                      'up_cutoff': CFG.pseudolbl_up,
                                      'low_cutoff': CFG.pseudolbl_low,
                                     }
                                  );
        
    # Initializig I-O for second stage pseudo labels:-
    if CFG.test_req == "Y":
        methods = ["LGBM1R", "XGB1R", "LGBM2R"];
    else:
        methods = list(Mdl_Master.keys());
        
    OOF_Preds = pd.DataFrame(columns = methods);
    Mdl_Preds = pd.DataFrame(index = pp.sub_fl['id'], columns = methods);
    FtreImp   = pd.DataFrame(index = sel_cols[1:], columns = methods);
    Scores    = pd.DataFrame(columns = methods);
    
    PrintColor(f"\n---> Selected model options- ");
    pprint(methods, depth = 1, width = 100, indent = 5);
    
    PrintColor(f"\n{'-' * 25} ML model training- Stage2 Pseudo Labels {'-' * 25}\n", 
               color = Fore.MAGENTA
              );
    for method in tqdm(methods, "ML models----"): TrainMdl(method);
    
    PrintColor(f"\n{'-' * 20} OOF CV scores across methods- Stage2 Pseudo Labels {'-' * 20}\n", 
                   color = Fore.MAGENTA);
    display(pd.concat([Scores.mean(axis = 0), Scores.std(axis = 0)], axis=1).\
            rename(columns = {0: 'Mean', 1: 'Std'}).T.\
            style.format(precision = 6).\
            background_gradient(subset = methods, cmap = 'cubehelix', axis=1)
           ); 
    
elif CFG.ML == "Y":
    PrintColor(f"\n{'-' * 25} ML model training {'-' * 25}\n", color = Fore.MAGENTA);
    for method in tqdm(methods, "ML models----"): 
        TrainMdl(method);

    PrintColor(f"\n{'-' * 20} OOF CV scores across methods {'-' * 20}\n", 
               color = Fore.MAGENTA);
    display(pd.concat([Scores.mean(axis = 0), Scores.std(axis = 0)], axis=1).\
            rename(columns = {0: 'Mean', 1: 'Std'}).T.\
            style.format(precision = 6).\
            background_gradient(subset = methods, cmap = 'cubehelix', axis=1)
           );    
else:
    PrintColor(f"\nML models are not needed\n", color = Fore.RED);    

collect();
print();
# Out:
# ------------------------- ML model training -------------------------
# ML models----:   0%|          | 0/7 [00:00<?, ?it/s]
# Fold0     OOF = 52.97773 | Train = 39.34751| CB1R
# Fold1     OOF = 51.09646 | Train = 42.82021| CB1R
# Fold2     OOF = 54.96005 | Train = 36.44385| CB1R
# Fold3     OOF = 48.50503 | Train = 37.34282| CB1R
# Fold4     OOF = 56.02320 | Train = 36.79085| CB1R
# Fold5     OOF = 55.69291 | Train = 40.97285| CB1R
# Fold6     OOF = 54.19394 | Train = 36.40278| CB1R
# Fold7     OOF = 55.86542 | Train = 36.59004| CB1R
# Fold8     OOF = 56.18109 | Train = 36.49769| CB1R
# Fold9     OOF = 49.51590 | Train = 35.41837| CB1R
# --> CB1R------ CV = 53.501174
#
# Fold0     OOF = 53.63911 | Train = 45.85500| CB2R
# Fold1     OOF = 52.53275 | Train = 48.03042| CB2R
# Fold2     OOF = 53.99910 | Train = 46.52537| CB2R
# Fold3     OOF = 49.32405 | Train = 45.99340| CB2R
# Fold4     OOF = 55.71626 | Train = 46.17558| CB2R
# Fold5     OOF = 55.05775 | Train = 45.99927| CB2R
# Fold6     OOF = 57.41939 | Train = 45.91466| CB2R
# Fold7     OOF = 57.79522 | Train = 46.41520| CB2R
# Fold8     OOF = 62.19491 | Train = 45.30684| CB2R
# Fold9     OOF = 51.11961 | Train = 45.61154| CB2R
# --> CB2R------ CV = 54.879813
#
# Fold0     OOF = 54.63526 | Train = 45.34054| CB3R
# Fold1     OOF = 52.83088 | Train = 46.01351| CB3R
# Fold2     OOF = 55.38853 | Train = 46.38489| CB3R
# Fold3     OOF = 50.22969 | Train = 45.60234| CB3R
# Fold4     OOF = 58.32939 | Train = 46.18761| CB3R
# Fold5     OOF = 55.61373 | Train = 45.94295| CB3R
# Fold6     OOF = 57.21438 | Train = 45.99189| CB3R
# Fold7     OOF = 59.45880 | Train = 46.62943| CB3R
# Fold8     OOF = 62.98337 | Train = 45.85836| CB3R
# Fold9     OOF = 51.69955 | Train = 46.45160| CB3R
# --> CB3R------ CV = 55.838358
#
# Fold0     OOF = 52.34877 | Train = 26.51208| XGB1R
# Fold1     OOF = 50.29694 | Train = 30.93005| XGB1R
# Fold2     OOF = 53.10873 | Train = 22.31293| XGB1R
# Fold3     OOF = 47.98083 | Train = 25.20929| XGB1R
# Fold4     OOF = 54.01534 | Train = 23.49878| XGB1R
# Fold5     OOF = 51.56479 | Train = 25.86255| XGB1R
# Fold6     OOF = 55.87308 | Train = 33.74252| XGB1R
# Fold7     OOF = 54.11429 | Train = 23.81189| XGB1R
# Fold8     OOF = 53.39270 | Train = 22.98639| XGB1R
# Fold9     OOF = 47.93188 | Train = 24.62425| XGB1R
# --> XGB1R----- CV = 52.062737
#
# Fold0     OOF = 53.19507 | Train = 38.23883| XGB2R
# Fold1     OOF = 50.41690 | Train = 33.76971| XGB2R
# Fold2     OOF = 53.72220 | Train = 32.94269| XGB2R
# Fold3     OOF = 51.32538 | Train = 36.15558| XGB2R
# Fold4     OOF = 56.13245 | Train = 30.06641| XGB2R
# Fold5     OOF = 54.36359 | Train = 40.06226| XGB2R
# Fold6     OOF = 59.48834 | Train = 34.88593| XGB2R
# Fold7     OOF = 55.77608 | Train = 27.49516| XGB2R
# Fold8     OOF = 53.78360 | Train = 27.70349| XGB2R
# Fold9     OOF = 51.02383 | Train = 30.18219| XGB2R
# --> XGB2R----- CV = 53.922741
#
# Fold0     OOF = 52.02863 | Train = 38.05139| XGB3R
# Fold1     OOF = 51.19417 | Train = 39.94373| XGB3R
# Fold2     OOF = 49.75351 | Train = 36.56186| XGB3R
# Fold3     OOF = 48.20905 | Train = 36.64185| XGB3R
# Fold4     OOF = 55.24516 | Train = 35.83081| XGB3R
# Fold5     OOF = 53.47339 | Train = 42.47046| XGB3R
# Fold6     OOF = 55.75113 | Train = 36.38483| XGB3R
# Fold7     OOF = 53.09637 | Train = 36.51666| XGB3R
# Fold8     OOF = 55.74445 | Train = 36.77850| XGB3R
# Fold9     OOF = 49.32828 | Train = 36.27223| XGB3R
# --> XGB3R----- CV = 52.382408
#
# Fold0     OOF = 51.07964 | Train = 49.74962| HGBR
# Fold1     OOF = 54.08529 | Train = 51.47098| HGBR
# Fold2     OOF = 57.15835 | Train = 49.99842| HGBR
# Fold3     OOF = 60.96348 | Train = 56.17726| HGBR
# Fold4     OOF = 56.74011 | Train = 49.59481| HGBR
# Fold5     OOF = 55.03116 | Train = 49.98812| HGBR
# Fold6     OOF = 58.61890 | Train = 50.08313| HGBR
# Fold7     OOF = 57.35332 | Train = 49.66175| HGBR
# Fold8     OOF = 57.80412 | Train = 49.23598| HGBR
# Fold9     OOF = 51.64107 | Train = 50.67302| HGBR
# --> HGBR------ CV = 56.047544
#
#
# -------------------- OOF CV scores across methods --------------------
# <style type="text/css">
# #T_7d984_row0_col0 {
#   background-color: #3a7533;
#   color: #f1f1f1;
# }
# #T_7d984_row0_col1 {
#   background-color: #cf9fdd;
#   color: #000000;
# }
# #T_7d984_row0_col2 {
#   background-color: #e7f8f1;
#   color: #000000;
# }
# #T_7d984_row0_col3, #T_7d984_row1_col3 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_7d984_row0_col4 {
#   background-color: #877a3a;
#   color: #f1f1f1;
# }
# #T_7d984_row0_col5 {
#   background-color: #180f25;
#   color: #f1f1f1;
# }
# #T_7d984_row0_col6, #T_7d984_row1_col2 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_7d984_row1_col0 {
#   background-color: #17364c;
#   color: #f1f1f1;
# }
# #T_7d984_row1_col1 {
#   background-color: #cce9ef;
#   color: #000000;
# }
# #T_7d984_row1_col4, #T_7d984_row1_col5 {
#   background-color: #191129;
#   color: #f1f1f1;
# }
# #T_7d984_row1_col6 {
#   background-color: #4c792f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7d984">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d984_level0_col0" class="col_heading level0 col0" >CB1R</th>
#       <th id="T_7d984_level0_col1" class="col_heading level0 col1" >CB2R</th>
#       <th id="T_7d984_level0_col2" class="col_heading level0 col2" >CB3R</th>
#       <th id="T_7d984_level0_col3" class="col_heading level0 col3" >XGB1R</th>
#       <th id="T_7d984_level0_col4" class="col_heading level0 col4" >XGB2R</th>
#       <th id="T_7d984_level0_col5" class="col_heading level0 col5" >XGB3R</th>
#       <th id="T_7d984_level0_col6" class="col_heading level0 col6" >HGBR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d984_level0_row0" class="row_heading level0 row0" >Mean</th>
#       <td id="T_7d984_row0_col0" class="data row0 col0" >53.501174</td>
#       <td id="T_7d984_row0_col1" class="data row0 col1" >54.879813</td>
#       <td id="T_7d984_row0_col2" class="data row0 col2" >55.838358</td>
#       <td id="T_7d984_row0_col3" class="data row0 col3" >52.062732</td>
#       <td id="T_7d984_row0_col4" class="data row0 col4" >53.922742</td>
#       <td id="T_7d984_row0_col5" class="data row0 col5" >52.382410</td>
#       <td id="T_7d984_row0_col6" class="data row0 col6" >56.047544</td>
#     </tr>
#     <tr>
#       <th id="T_7d984_level0_row1" class="row_heading level0 row1" >Std</th>
#       <td id="T_7d984_row1_col0" class="data row1 col0" >2.856662</td>
#       <td id="T_7d984_row1_col1" class="data row1 col1" >3.682094</td>
#       <td id="T_7d984_row1_col2" class="data row1 col2" >3.823751</td>
#       <td id="T_7d984_row1_col3" class="data row1 col3" >2.636850</td>
#       <td id="T_7d984_row1_col4" class="data row1 col4" >2.738975</td>
#       <td id="T_7d984_row1_col5" class="data row1 col5" >2.743473</td>
#       <td id="T_7d984_row1_col6" class="data row1 col6" >3.095930</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 12min 1s, sys: 35.6 s, total: 12min 37s
# Wall time: 3min 46s

# %%
# %%time 

# Analysing the model results and feature importances:-
if CFG.ML == "Y":
    fig, axes = plt.subplots(len(methods), 1, figsize = (25, len(methods) * 10),
                             gridspec_kw = {'hspace': 0.2, 'wspace': 0.2},
                            );
    
    for i, col in enumerate(methods):
        try: 
            ax = axes[i];
        except: 
            ax = axes[0];
        FtreImp[col].plot.barh(ax = ax, color = '#0073e6');
        ax.set_title(f"{col} Importances", **CFG.title_specs);
        ax.set(xlabel = '', ylabel = '');
        
    plt.suptitle(f"ML Model prediction feature importance", y = 0.9125, **CFG.title_specs);
    plt.tight_layout();
    plt.show();  

collect();
# Out:
# CPU times: user 2.67 s, sys: 277 ms, total: 2.95 s
# Wall time: 2.74 s

# %% [markdown]
# # Inferences
#
# 1. We have to drop some features/ add secondary features to ensure better CV results. Train-OOF scores are very stable.
# 2. We need to fine tune model parameters.
# 3. We could try other models methods too, perhaps some simple ones will be good enough.
# 4. Custom objective/metric class will also work in this case.
# 5. We can explore pseudo labels also

# %% [markdown]
# # Ensemble and Submission

# %%
# %%time 

if CFG.ensemble_req == "Y" and CFG.optuna_req == "Y":
    def Objective(trial):
        "This function defines the objective for the optuna ensemble using variable models";

        global OOF_Preds, all_cv, ytrain, methods, y_grp;

        # Define the weights for the predictions from each model:-
        weights  = [trial.suggest_float(f"M{n}", 0.0001, 0.9999, step = 0.001) \
                    for n in range(len(OOF_Preds[methods].columns))
                   ];

        # Calculating the CV-score for the weighted predictions on the competition data only:-
        scores = [];  
        cv     = all_cv[CFG.enscv_mthod];
        X,y    = OOF_Preds[methods], ytrain[0: len(OOF_Preds)];

        for fold_nb, (train_idx, dev_idx) in enumerate(cv.split(X,y_grp[0: len(OOF_Preds)])):
            Xtr, Xdev = X.iloc[train_idx], X.iloc[dev_idx];
            ytr, ydev = y.loc[Xtr.index],  y.loc[Xdev.index];
            scores.append(ScoreMetric(ydev, np.average(Xdev, axis=1, weights = weights)));

        collect();
        clear_output();
        return np.mean(scores);
    
clear_output();
print();
collect();
# Out:
# CPU times: user 220 ms, sys: 3.79 ms, total: 224 ms
# Wall time: 221 ms

# %%
# %%time 

if CFG.ensemble_req == "Y" and CFG.optuna_req == "Y":   
    PrintColor(f"\n{'-' * 20} Creating an Optuna Ensemble {'-' * 20}\n", 
               color = Fore.MAGENTA);   
    
    study = optuna.create_study(direction  = CFG.metric_obj, 
                                study_name = "OptunaEnsemble", 
                                sampler    = TPESampler(seed = CFG.state)
                               );
    study.optimize(Objective, 
                   n_trials          = CFG.ntrials, 
                   gc_after_trial    = True,
                   show_progress_bar = True
                  );
    weights       = study.best_params;
    clear_output();
    
    PrintColor(f"\n--> Post ensemble weights\n");
    pprint(weights, indent = 5, width = 10, depth = 1);
    PrintColor(f"\n--> Best ensemble CV score = {study.best_value :.5f}\n");
    
    # Making weighted predictions on the test set:-
    sub_fl[CFG.target] = np.average(Mdl_Preds[methods], weights = list(weights.values()),
                                    axis=1
                                   ) / CFG.tgt_scl_fct;
    
    # Making OOF predictions:-
    OOF_Preds["Optuna"] = np.average(OOF_Preds[methods], weights = list(weights.values()),
                                     axis=1
                                    ) / CFG.tgt_scl_fct;
    
    PrintColor(f"\n--> Post ensemble test-set predictions\n");
    display(sub_fl.head(5).style.format(precision = 5)); 
      
collect();
# Out:
# CPU times: user 216 ms, sys: 0 ns, total: 216 ms
# Wall time: 214 ms

# %%
# %%time 

if CFG.ensemble_req == "Y" and CFG.LAD_req == "Y":
    PrintColor(f"\n{'-' * 20} Creating an LADR Ensemble {'-' * 20}\n", color = Fore.MAGENTA); 
    X,y        = OOF_Preds[methods], ytrain[0: len(OOF_Preds)];
    model      = LADR();
    test_preds = 0;
    scores     = [];
    cv         = all_cv[CFG.enscv_method];
    ens_preds  = pd.DataFrame(columns = ["LAD"]);

    for fold_nb, (train_idx, dev_idx) in enumerate(cv.split(X, y_grp[0:len(X)])):
        Xtr  = X.iloc[train_idx];  
        Xdev = X.iloc[dev_idx]; 
        ytr  = y.loc[y.index.isin(Xtr.index)];
        ydev = y.loc[y.index.isin(Xdev.index)];

        model.fit(Xtr, ytr);
        dev_preds  = PostProcessPred(model.predict(Xdev), CFG.pstprcs_train);
        score      = ScoreMetric(ydev, dev_preds);
        test_preds = test_preds + \
        PostProcessPred(model.predict(Mdl_Preds[methods]), CFG.pstprcs_train);
        scores.append(score);
        
        ens_preds = pd.concat([ens_preds, 
                               pd.DataFrame(dev_preds, columns = ['LAD'], index = Xdev.index)], 
                              axis=0
                             );

    test_preds         = test_preds/ (CFG.n_splits * CFG.n_repeats);
    sub_fl[CFG.target] = test_preds/ CFG.tgt_scl_fct;
    ens_preds          = ens_preds.groupby(level = 0).mean().values;
    OOF_Preds["LAD"]   = ens_preds;
    
    PrintColor(f"---> OOF scores for the LAD ensemble");
    with np.printoptions(linewidth = 160, precision= 4):
        pprint(np.array(scores), indent = 10, depth = 1);
        PrintColor(f"---> Mean OOF scores for the LAD ensemble = {np.mean(scores):.5f}");
        
    PrintColor(f"\n--> Post ensemble test-set predictions\n");
    display(sub_fl.head(5).style.format(precision = 5)); 
    
    # Analyzing the grouped predictions for edge case issues:-  
    PrintColor(f"\n--> Analysis of grouped predictions on OOF data\n");
    OOF_Preds['Grp'] = y_grp[0: len(OOF_Preds)];
    OOF_Preds        = pd.concat([OOF_Preds, ytrain[0: len(OOF_Preds)]], axis=1);
    
    display(OOF_Preds[["Grp", CFG.target, "LAD"]].\
            groupby("Grp").\
            apply(lambda x: ScoreMetric(x[CFG.target], x["LAD"])).\
            to_frame().rename(columns = {0: "OOFScore"}).\
            style.format(precision = 4).\
            background_gradient("icefire")
           );

print();
collect();
# Out:
# -------------------- Creating an LADR Ensemble --------------------
#
# ---> OOF scores for the LAD ensemble
# array([50.3856, 54.7978, 51.6832, 50.1917, 53.5299, 48.8608, 60.3667, 50.3412, 50.1836, 48.6553])
# ---> Mean OOF scores for the LAD ensemble = 51.89959
#
# --> Post ensemble test-set predictions
# <style type="text/css">
# </style>
# <table id="T_e9353">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9353_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_e9353_level0_col1" class="col_heading level0 col1" >Hardness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9353_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e9353_row0_col0" class="data row0 col0" >10407</td>
#       <td id="T_e9353_row0_col1" class="data row0 col1" >2.68739</td>
#     </tr>
#     <tr>
#       <th id="T_e9353_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e9353_row1_col0" class="data row1 col0" >10408</td>
#       <td id="T_e9353_row1_col1" class="data row1 col1" >2.57803</td>
#     </tr>
#     <tr>
#       <th id="T_e9353_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e9353_row2_col0" class="data row2 col0" >10409</td>
#       <td id="T_e9353_row2_col1" class="data row2 col1" >6.02063</td>
#     </tr>
#     <tr>
#       <th id="T_e9353_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e9353_row3_col0" class="data row3 col0" >10410</td>
#       <td id="T_e9353_row3_col1" class="data row3 col1" >4.52283</td>
#     </tr>
#     <tr>
#       <th id="T_e9353_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e9353_row4_col0" class="data row4 col0" >10411</td>
#       <td id="T_e9353_row4_col1" class="data row4 col1" >5.16022</td>
#     </tr>
#   </tbody>
# </table>
# --> Analysis of grouped predictions on OOF data
# <style type="text/css">
# #T_b7340_row0_col0 {
#   background-color: #2e2d48;
#   color: #f1f1f1;
# }
# #T_b7340_row1_col0 {
#   background-color: #3e3c70;
#   color: #f1f1f1;
# }
# #T_b7340_row2_col0, #T_b7340_row11_col0 {
#   background-color: #4560c1;
#   color: #f1f1f1;
# }
# #T_b7340_row3_col0, #T_b7340_row14_col0 {
#   background-color: #4c9ccd;
#   color: #f1f1f1;
# }
# #T_b7340_row4_col0 {
#   background-color: #3885d0;
#   color: #f1f1f1;
# }
# #T_b7340_row5_col0 {
#   background-color: #ef8748;
#   color: #f1f1f1;
# }
# #T_b7340_row6_col0 {
#   background-color: #24232e;
#   color: #f1f1f1;
# }
# #T_b7340_row7_col0 {
#   background-color: #5da9cd;
#   color: #f1f1f1;
# }
# #T_b7340_row8_col0 {
#   background-color: #78b9ce;
#   color: #000000;
# }
# #T_b7340_row9_col0 {
#   background-color: #4394ce;
#   color: #f1f1f1;
# }
# #T_b7340_row10_col0, #T_b7340_row23_col0 {
#   background-color: #4798ce;
#   color: #f1f1f1;
# }
# #T_b7340_row12_col0 {
#   background-color: #5aa7cd;
#   color: #f1f1f1;
# }
# #T_b7340_row13_col0 {
#   background-color: #bde7db;
#   color: #000000;
# }
# #T_b7340_row15_col0 {
#   background-color: #3f90ce;
#   color: #f1f1f1;
# }
# #T_b7340_row16_col0 {
#   background-color: #63adcd;
#   color: #f1f1f1;
# }
# #T_b7340_row17_col0, #T_b7340_row34_col0 {
#   background-color: #50a0cd;
#   color: #f1f1f1;
# }
# #T_b7340_row18_col0 {
#   background-color: #4e9ecd;
#   color: #f1f1f1;
# }
# #T_b7340_row19_col0 {
#   background-color: #6bb2cd;
#   color: #f1f1f1;
# }
# #T_b7340_row20_col0 {
#   background-color: #3a73ce;
#   color: #f1f1f1;
# }
# #T_b7340_row21_col0 {
#   background-color: #377fd0;
#   color: #f1f1f1;
# }
# #T_b7340_row22_col0 {
#   background-color: #363459;
#   color: #f1f1f1;
# }
# #T_b7340_row24_col0, #T_b7340_row33_col0 {
#   background-color: #65afcd;
#   color: #f1f1f1;
# }
# #T_b7340_row25_col0, #T_b7340_row26_col0 {
#   background-color: #7bbbce;
#   color: #000000;
# }
# #T_b7340_row27_col0 {
#   background-color: #93cad1;
#   color: #000000;
# }
# #T_b7340_row28_col0 {
#   background-color: #afddd7;
#   color: #000000;
# }
# #T_b7340_row29_col0 {
#   background-color: #a9d9d6;
#   color: #000000;
# }
# #T_b7340_row30_col0 {
#   background-color: #b4e1d9;
#   color: #000000;
# }
# #T_b7340_row31_col0 {
#   background-color: #9bcfd3;
#   color: #000000;
# }
# #T_b7340_row32_col0 {
#   background-color: #87c2cf;
#   color: #000000;
# }
# #T_b7340_row35_col0 {
#   background-color: #4956b3;
#   color: #f1f1f1;
# }
# #T_b7340_row36_col0 {
#   background-color: #fabb8b;
#   color: #000000;
# }
# #T_b7340_row37_col0 {
#   background-color: #3781d0;
#   color: #f1f1f1;
# }
# #T_b7340_row38_col0 {
#   background-color: #377cd0;
#   color: #f1f1f1;
# }
# #T_b7340_row39_col0 {
#   background-color: #46458a;
#   color: #f1f1f1;
# }
# #T_b7340_row40_col0 {
#   background-color: #3d3b6d;
#   color: #f1f1f1;
# }
# #T_b7340_row41_col0 {
#   background-color: #262534;
#   color: #f1f1f1;
# }
# #T_b7340_row42_col0 {
#   background-color: #352024;
#   color: #f1f1f1;
# }
# #T_b7340_row43_col0 {
#   background-color: #231e1e;
#   color: #f1f1f1;
# }
# #T_b7340_row44_col0 {
#   background-color: #46242b;
#   color: #f1f1f1;
# }
# #T_b7340_row45_col0 {
#   background-color: #522731;
#   color: #f1f1f1;
# }
# #T_b7340_row46_col0 {
#   background-color: #ab3043;
#   color: #f1f1f1;
# }
# #T_b7340_row47_col0 {
#   background-color: #c53c3c;
#   color: #f1f1f1;
# }
# #T_b7340_row48_col0 {
#   background-color: #ffd4ac;
#   color: #000000;
# }
# #T_b7340_row49_col0 {
#   background-color: #9c2f45;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b7340">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b7340_level0_col0" class="col_heading level0 col0" >OOFScore</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Grp</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7340_level0_row0" class="row_heading level0 row0" >100</th>
#       <td id="T_b7340_row0_col0" class="data row0 col0" >170.4831</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row1" class="row_heading level0 row1" >130</th>
#       <td id="T_b7340_row1_col0" class="data row1 col0" >151.1235</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row2" class="row_heading level0 row2" >150</th>
#       <td id="T_b7340_row2_col0" class="data row2 col0" >116.7731</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row3" class="row_heading level0 row3" >180</th>
#       <td id="T_b7340_row3_col0" class="data row3 col0" >75.0305</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row4" class="row_heading level0 row4" >200</th>
#       <td id="T_b7340_row4_col0" class="data row4 col0" >92.3064</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row5" class="row_heading level0 row5" >209</th>
#       <td id="T_b7340_row5_col0" class="data row5 col0" >360.9243</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row6" class="row_heading level0 row6" >220</th>
#       <td id="T_b7340_row6_col0" class="data row6 col0" >187.1733</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row7" class="row_heading level0 row7" >230</th>
#       <td id="T_b7340_row7_col0" class="data row7 col0" >64.2885</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row8" class="row_heading level0 row8" >250</th>
#       <td id="T_b7340_row8_col0" class="data row8 col0" >50.9543</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row9" class="row_heading level0 row9" >260</th>
#       <td id="T_b7340_row9_col0" class="data row9 col0" >81.1753</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row10" class="row_heading level0 row10" >280</th>
#       <td id="T_b7340_row10_col0" class="data row10 col0" >78.3218</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row11" class="row_heading level0 row11" >290</th>
#       <td id="T_b7340_row11_col0" class="data row11 col0" >115.6675</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row12" class="row_heading level0 row12" >300</th>
#       <td id="T_b7340_row12_col0" class="data row12 col0" >66.2617</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row13" class="row_heading level0 row13" >320</th>
#       <td id="T_b7340_row13_col0" class="data row13 col0" >12.8769</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row14" class="row_heading level0 row14" >330</th>
#       <td id="T_b7340_row14_col0" class="data row14 col0" >75.1672</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row15" class="row_heading level0 row15" >350</th>
#       <td id="T_b7340_row15_col0" class="data row15 col0" >83.5662</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row16" class="row_heading level0 row16" >360</th>
#       <td id="T_b7340_row16_col0" class="data row16 col0" >60.2830</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row17" class="row_heading level0 row17" >380</th>
#       <td id="T_b7340_row17_col0" class="data row17 col0" >71.0375</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row18" class="row_heading level0 row18" >400</th>
#       <td id="T_b7340_row18_col0" class="data row18 col0" >73.4868</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row19" class="row_heading level0 row19" >410</th>
#       <td id="T_b7340_row19_col0" class="data row19 col0" >57.1497</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row20" class="row_heading level0 row20" >430</th>
#       <td id="T_b7340_row20_col0" class="data row20 col0" >103.5289</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row21" class="row_heading level0 row21" >450</th>
#       <td id="T_b7340_row21_col0" class="data row21 col0" >95.8570</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row22" class="row_heading level0 row22" >469</th>
#       <td id="T_b7340_row22_col0" class="data row22 col0" >162.4878</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row23" class="row_heading level0 row23" >480</th>
#       <td id="T_b7340_row23_col0" class="data row23 col0" >78.3834</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row24" class="row_heading level0 row24" >500</th>
#       <td id="T_b7340_row24_col0" class="data row24 col0" >59.7483</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_level0_row25" class="row_heading level0 row25" >530</th>
#       <td id="T_b7340_row25_col0" class="data row25 col0" >48.0719</td>
#     </tr>
#     <tr>
#       <th id="T_b7340_leve
# CPU times: user 7.86 s, sys: 6.03 s, total: 13.9 s
# Wall time: 5.52 s

# %%
OOF_Preds
# Out:
#              CB1R        CB2R        CB3R       XGB1R       XGB2R       XGB3R  \
# 0      634.326366  613.457945  604.578349  621.663330  628.867920  621.014648
# 1      582.031512  565.511927  559.888511  577.160400  576.466003  575.166870
# 2      364.004291  384.059363  376.369902  440.676514  453.044861  451.051849
# 3      603.531732  596.822418  597.307389  598.759094  600.978577  595.833679
# 4      592.937667  587.742161  585.109410  592.885193  595.264221  585.128235
# ...           ...         ...         ...         ...         ...         ...
# 10396  571.299052  573.274369  575.344948  575.013916  588.504944  576.217957
# 10397  502.914209  510.259136  508.973998  514.135559  524.017090  509.419159
# 10398  163.693429  195.041867  163.490618  204.924606  202.074005  198.094604
# 10399  559.057891  560.398434  557.691932  570.852356  528.621155  574.964417
# 10400  583.505542  597.004524  591.827682  607.530457  620.380615  600.112488
#
#              HGBR         LAD  Grp  Hardness
# 0      603.137017  631.832517  600       600
# 1      564.713209  581.840652  650       650
# 2      408.600790  447.028205  250       250
# 3      593.347609  602.931566  600       600
# 4      578.723494  597.882033  600       600
# ...           ...         ...  ...       ...
# 10396  562.551238  582.501763  400       400
# 10397  509.474609  517.481523  500       500
# 10398  220.591179  192.600723  180       180
# 10399  573.702081  556.812641  600       600
# 10400  598.236796  614.140557  650       650
#
# [10401 rows x 10 columns]

# %%
# Scores

# %%
# %%time 

if CFG.ensemble_req == "Y":
    sub_fl[['id', CFG.target]].to_csv(f"SubNoPP_V{CFG.version_nb}.csv", index = None);
    
    PrintColor(f"\n---> Blending with good public work\n");
    sub_fl['nb1'] = \
    pd.read_csv(f"/home/jupyter/kaggle-notebooks/Goodnotebooks/submission (1).csv")[CFG.target].values;
    sub_fl['nb2'] = \
    pd.read_csv(f"/home/jupyter/kaggle-notebooks/Goodnotebooks/submission (2).csv")[CFG.target].values;   
    
    sub_fl[CFG.target] = PostProcessPred(sub_fl[CFG.target] * 0.1 + sub_fl['nb1'] * 0.4 + sub_fl['nb2'] * 0.5, 
                                         "Y", 1);
       
    PrintColor(f"\n---> Submission file- final check after post-processing\n");
    display(sub_fl[CFG.target].describe());
    sub_fl[['id', CFG.target]].to_csv(f"Submission_V{CFG.version_nb}.csv", index = None);
    
    PrintColor(f"\n---> Submission file after post-processing\n");
    display(sub_fl[['id', CFG.target]].head(10).style.format(precision = 3));
    
if CFG.ML == "Y":  
    OOF_Preds.add_prefix(f"V{CFG.version_nb}_").to_csv(f"OOF_Preds_V{CFG.version_nb}.csv");
    Mdl_Preds.add_prefix(f"V{CFG.version_nb}_").to_csv(f"Mdl_Preds_V{CFG.version_nb}.csv"); 
    if isinstance(Scores, pd.DataFrame) == True:
        Scores.to_csv(f"Scores_V{CFG.version_nb}.csv");
          
collect();
print();
# Out:
# ---> Blending with good public work
#
#
# ---> Submission file- final check after post-processing
# count    6939.000000
# mean        4.648375
# std         1.472283
# min         1.359883
# 25%         2.769129
# 50%         5.688694
# 75%         5.791462
# max         6.633198
# Name: Hardness, dtype: float64
# ---> Submission file after post-processing
# <style type="text/css">
# </style>
# <table id="T_e3c6c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3c6c_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_e3c6c_level0_col1" class="col_heading level0 col1" >Hardness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3c6c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3c6c_row0_col0" class="data row0 col0" >10407</td>
#       <td id="T_e3c6c_row0_col1" class="data row0 col1" >2.504</td>
#     </tr>
#     <tr>
#       <th id="T_e3c6c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e3c6c_row1_col0" class="data row1 col0" >10408</td>
#       <td id="T_e3c6c_row1_col1" class="data row1 col1" >2.342</td>
#     </tr>
#     <tr>
#       <th id="T_e3c6c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e3c6c_row2_col0" class="data row2 col0" >10409</td>
#       <td id="T_e3c6c_row2_col1" class="data row2 col1" >5.806</td>
#     </tr>
#     <tr>
#       <th id="T_e3c6c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e3c6c_row3_col0" class="data row3 col0" >10410</td>
#       <td id="T_e3c6c_row3_col1" class="data row3 col1" >4.407</td>
#     </tr>
#     <tr>
#       <th id="T_e3c6c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e3c6c_row4_col0" class="data row4 col0" >10411</td>
#       <td id="T_e3c6c_row4_col1" class="data row4 col1" >5.678</td>
#     </tr>
#     <tr>
#       <th id="T_e3c6c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e3c6c_row5_col0" class="data row5 col0" >10412</td>
#       <td id="T_e3c6c_row5_col1" class="data row5 col1" >5.766</td>
#     </tr>
#     <tr>
#       <th id="T_e3c6c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e3c6c_row6_col0" class="data row6 col0" >10413</td>
#       <td id="T_e3c6c_row6_col1" class="data row6 col1" >2.943</td>
#     </tr>
#     <tr>
#       <th id="T_e3c6c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e3c6c_row7_col0" class="data row7 col0" >10414</td>
#       <td id="T_e3c6c_row7_col1" class="data row7 col1" >5.655</td>
#     </tr>
#     <tr>
#       <th id="T_e3c6c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e3c6c_row8_col0" class="data row8 col0" >10415</td>
#       <td id="T_e3c6c_row8_col1" class="data row8 col1" >2.760</td>
#     </tr>
#     <tr>
#       <th id="T_e3c6c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e3c6c_row9_col0" class="data row9 col0" >10416</td>
#       <td id="T_e3c6c_row9_col1" class="data row9 col1" >5.587</td>
#     </tr>
#   </tbody>
# </table>
# CPU times: user 722 ms, sys: 24.2 ms, total: 746 ms
# Wall time: 748 ms

# %%
CFG.ML
# Out:
# 'Y'
